# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import os
import pathlib
import sys

# %%
# go to parent directory
os.chdir("..")
import paths

REPO_DIR = paths.get_repo_path()
ROOT_DIR = REPO_DIR / "CIFAR-10"

# set path to repo_dir
os.chdir(REPO_DIR)

# %% [markdown]
# ## Data

# %%
CLASS_NAMES = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]
NUM_CLASSES = len(CLASS_NAMES)

# %%
from sklearn.preprocessing import LabelEncoder

def give_class_name(y:np.ndarray) -> np.ndarray:
    enc = LabelEncoder().fit(CLASS_NAMES)
    y_labeled = enc.inverse_transform(y)
    
    return y_labeled

# %% [markdown]
# ### Load CIFAR-10 data

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.cifar10.load_data()

# Image scaling to 0-1
# train_images = train_images / 255.0
# test_images = test_images / 255.0

if train_labels.ndim == 2:
    train_labels = train_labels.flatten()
    test_labels = test_labels.flatten()


total_data = f"Total Data on RAM -{(train_images.size + test_images.size) / 1024**2 : .2f} MB"
total_data
# Out:
# 'Total Data on RAM - 175.78 MB'

# %% [markdown]
# ### Displaying the first image in the training set

# %%
# display images in a grid function
def display_image_grid(images, labels, pred_val=None,shape=(5, 5), figsize=(10, 10)):
    plt.figure(figsize=figsize)
    m = shape[0] * shape[1]
    
    if images.shape[0] < m:
        raise ValueError("images.shape[0] must equal shape[0] * shape[1]")
    
    if labels.shape[0] != images.shape[0]:
        raise ValueError("labels.shape[0] must equal images.shape[0]")
    
    if pred_val is not None and pred_val.shape[0] != images.shape[0]:
        raise ValueError("pred_val.shape[0] must equal images.shape[0]")
    
    for i in range(m):
        plt.subplot(shape[0], shape[1], i+1)
        plt.imshow(images[i], cmap="gray", interpolation="none")
        title = labels[i]
        if pred_val is not None:
            title = f"{pred_val[i]}"
            if pred_val[i] != labels[i]:
                title += f"(incorrect, {labels[i]})"
        plt.title(title)
        plt.axis("off")
    plt.show()

# %%
# display 25 random images from the training set
rnd_pts = np.random.randint(0, train_images.shape[0], 25)
images = train_images[rnd_pts, :, :]
labels = train_labels[rnd_pts]

display_image_grid(images, give_class_name(labels))

# %% [markdown]
# ### Preprocessing the data

# %%
# One hot encode the labels
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(train_labels)
y_test = to_categorical(test_labels)

# %% [markdown]
# ## MODELS

# %%
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Normalization, Rescaling

# %%
MODELS_PATH = ROOT_DIR / "models"
INPUT_SHAPE = train_images.shape[1:]

# %%
def predict_label(images, model):
    predictions = model.predict(images)
    return predictions.argmax(axis=1)

# %% [markdown]
# ### Create Models
#
# TODO List -
#    - Improve Simple Sequential Model
#      - Read and see other Models
#    - Add more Models
#      - Model with VGG-Like Blocks
#      - Model with residual Blocks
#      - Model With Inseption Blocks
#      - Model With Mobile Blocks
#      - Transfer Learning Models
#        - VGG
#        - ResNet
#        - Inseption
#        - Mobile

# %% [markdown]
# #### Simple Sequential Model

# %%
from tensorflow.keras.models import Sequential

def simple_sequential_model(input_shape, num_classes):
    model = Sequential()
    
    model.add(Rescaling(1./255, input_shape=input_shape))
    model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding="same"))
    model.add(Normalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding="same"))
    model.add(Normalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(10, activation='softmax'))
    
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %% [markdown]
# ### Training

# %%
# ploting the model training history

def plot_model_performance(history, figsize=(10, 10)):
    preformance = {key: val for key, val in history.history.items() if "loss" not in key}
    losses = {key: val for key, val in history.history.items() if "loss" in key}
    
    plt.figure(figsize=figsize)
    plt.title('Model Performance')
    for key, val in preformance.items():
        plt.plot(val, label=key)
    plt.legend(preformance.keys())
    plt.xlabel('Epoch')
    
    plt.figure(figsize=figsize)
    plt.title('Model Losses')
    for key, val in losses.items():
        plt.plot(val, label=key)
    plt.legend(losses.keys())
    plt.xlabel('Epoch')
    
    plt.show()

# %% [markdown]
# #### Simple Sequential Model

# %%
model = simple_sequential_model(INPUT_SHAPE, NUM_CLASSES)
model.summary()
# Out:
# Metal device set to: Apple M1
#
# systemMemory: 8.00 GB
# maxCacheSize: 2.67 GB
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 32, 32, 3)         0
#
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  normalization (Normalizatio  (None, 32, 32, 32)       65
#  n)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 64)        18496
#
#  normalization_1 (Normalizat  (None, 16, 16, 64)       129
#  ion)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 128)               524416
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 32)                4128
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 10)                330
#
# =================================================================
# Total params: 548,460
# Trainable params: 548,266
# Non-trainable params: 194
# _________________________________________________________________
# 2022-06-09 07:17:07.992306: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-06-09 07:17:07.992641: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# callbacks
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint

# Early stopping
es = EarlyStopping(monitor='val_accuracy', verbose=1, patience=5, mode='max')
# learning rate scheduler
lrd = LearningRateScheduler(lambda epoch: 1 / 10**(3 + epoch // 10))
# model checkpoint
mdl_check = ModelCheckpoint(filepath=f'{MODELS_PATH}/simple_sequential.h5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

callbacks = [es, mdl_check]

# %%
history = model.fit(train_images, y_train, 
                    epochs=30, batch_size=64,
                    validation_split=0.2, callbacks=callbacks)
# Out:
# Epoch 1/30
# 2022-06-09 07:17:10.522054: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-06-09 07:17:10.849812: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 625/625 [==============================] - ETA: 0s - loss: 1.7330 - accuracy: 0.3631
# 2022-06-09 07:17:20.559247: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_accuracy improved from -inf to 0.51620, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 11s 17ms/step - loss: 1.7330 - accuracy: 0.3631 - val_loss: 1.3491 - val_accuracy: 0.5162
# Epoch 2/30
# 625/625 [==============================] - ETA: 0s - loss: 1.3540 - accuracy: 0.5142
# Epoch 2: val_accuracy improved from 0.51620 to 0.59290, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 11s 17ms/step - loss: 1.3540 - accuracy: 0.5142 - val_loss: 1.1642 - val_accuracy: 0.5929
# Epoch 3/30
# 623/625 [============================>.] - ETA: 0s - loss: 1.2004 - accuracy: 0.5760
# Epoch 3: val_accuracy improved from 0.59290 to 0.61890, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 11s 18ms/step - loss: 1.2000 - accuracy: 0.5762 - val_loss: 1.0781 - val_accuracy: 0.6189
# Epoch 4/30
# 622/625 [============================>.] - ETA: 0s - loss: 1.0897 - accuracy: 0.6177
# Epoch 4: val_accuracy improved from 0.61890 to 0.64260, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 11s 18ms/step - loss: 1.0893 - accuracy: 0.6176 - val_loss: 1.0184 - val_accuracy: 0.6426
# Epoch 5/30
# 624/625 [============================>.] - ETA: 0s - loss: 1.0065 - accuracy: 0.6500
# Epoch 5: val_accuracy improved from 0.64260 to 0.66530, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 12s 20ms/step - loss: 1.0067 - accuracy: 0.6500 - val_loss: 0.9766 - val_accuracy: 0.6653
# Epoch 6/30
# 625/625 [==============================] - ETA: 0s - loss: 0.9365 - accuracy: 0.6754
# Epoch 6: val_accuracy improved from 0.66530 to 0.67470, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 13s 21ms/step - loss: 0.9365 - accuracy: 0.6754 - val_loss: 0.9454 - val_accuracy: 0.6747
# Epoch 7/30
# 624/625 [============================>.] - ETA: 0s - loss: 0.8835 - accuracy: 0.6962
# Epoch 7: val_accuracy improved from 0.67470 to 0.68750, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 14s 22ms/step - loss: 0.8834 - accuracy: 0.6962 - val_loss: 0.9090 - val_accuracy: 0.6875
# Epoch 8/30
# 624/625 [============================>.] - ETA: 0s - loss: 0.8305 - accuracy: 0.7129
# Epoch 8: val_accuracy improved from 0.68750 to 0.69530, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 16s 26ms/step - loss: 0.8304 - accuracy: 0.7129 - val_loss: 0.8828 - val_accuracy: 0.6953
# Epoch 9/30
# 624/625 [============================>.] - ETA: 0s - loss: 0.7808 - accuracy: 0.7326
# Epoch 9: val_accuracy improved from 0.69530 to 0.69580, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 16s 26ms/step - loss: 0.7810 - accuracy: 0.7325 - val_loss: 0.8826 - val_accuracy: 0.6958
# Epoch 10/30
# 625/625 [==============================] - ETA: 0s - loss: 0.7376 - accuracy: 0.7477
# Epoch 10: val_accuracy improved from 0.69580 to 0.70340, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 19s 31ms/step - loss: 0.7376 - accuracy: 0.7477 - val_loss: 0.8776 - val_accuracy: 0.7034
# Epoch 11/30
# 625/625 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.7622
# Epoch 11: val_accuracy improved from 0.70340 to 0.70610, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 19s 31ms/step - loss: 0.6936 - accuracy: 0.7622 - val_loss: 0.8857 - val_accuracy: 0.7061
# Epoch 12/30
# 625/625 [==============================] - ETA: 0s - loss: 0.6633 - accuracy: 0.7698
# Epoch 12: val_accuracy improved from 0.70610 to 0.70620, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 25s 41ms/step - loss: 0.6633 - accuracy: 0.7698 - val_loss: 0.8905 - val_accuracy: 0.7062
# Epoch 13/30
# 625/625 [==============================] - ETA: 0s - loss: 0.6330 - accuracy: 0.7831
# Epoch 13: val_accuracy improved from 0.70620 to 0.70670, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 26s 41ms/step - loss: 0.6330 - accuracy: 0.7831 - val_loss: 0.9042 - val_accuracy: 0.7067
# Epoch 14/30
# 624/625 [============================>.] - ETA: 0s - loss: 0.5960 - accuracy: 0.7954
# Epoch 14: val_accuracy improved from 0.70670 to 0.71440, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 24s 38ms/step - loss: 0.5963 - accuracy: 0.7953 - val_loss: 0.8928 - val_accuracy: 0.7144
# Epoch 15/30
# 624/625 [============================>.] - ETA: 0s - loss: 0.5655 - accuracy: 0.8066
# Epoch 15: val_accuracy improved from 0.71440 to 0.71470, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 24s 38ms/step - loss: 0.5652 - accuracy: 0.8066 - val_loss: 0.9110 - val_accuracy: 0.7147
# Epoch 16/30
# 624/625 [============================>.] - ETA: 0s - loss: 0.5425 - accuracy: 0.8116
# Epoch 16: val_accuracy did not improve from 0.71470
# 625/625 [==============================] - 23s 37ms/step - loss: 0.5424 - accuracy: 0.8117 - val_loss: 0.9537 - val_accuracy: 0.7074
# Epoch 17/30
# 625/625 [==============================] - ETA: 0s - loss: 0.5184 - accuracy: 0.8202
# Epoch 17: val_accuracy did not improve from 0.71470
# 625/625 [==============================] - 23s 36ms/step - loss: 0.5184 - accuracy: 0.8202 - val_loss: 0.9311 - val_accuracy: 0.7132
# Epoch 18/30
# 625/625 [==============================] - ETA: 0s - loss: 0.4858 - accuracy: 0.8317
# Epoch 18: val_accuracy did not improve from 0.71470
# 625/625 [==============================] - 22s 35ms/step - loss: 0.4858 - accuracy: 0.8317 - val_loss: 0.9802 - val_accuracy: 0.7104
# Epoch 19/30
# 625/625 [==============================] - ETA: 0s - loss: 0.4619 - accuracy: 0.8389
# Epoch 19: val_accuracy did not improve from 0.71470
# 625/625 [==============================] - 22s 34ms/step - loss: 0.4619 - accuracy: 0.8389 - val_loss: 0.9874 - val_accuracy: 0.7068
# Epoch 20/30
# 625/625 [==============================] - ETA: 0s - loss: 0.4467 - accuracy: 0.8466
# Epoch 20: val_accuracy did not improve from 0.71470
# 625/625 [==============================] - 22s 35ms/step - loss: 0.4467 - accuracy: 0.8466 - val_loss: 1.0349 - val_accuracy: 0.7125
# Epoch 20: early stopping

# %%
plot_model_performance(history)

# %%
model.evaluate(test_images, y_test)
# Out:
# 313/313 [==============================] - 2s 7ms/step - loss: 1.0426 - accuracy: 0.7099
# [1.0425612926483154, 0.7099000215530396]

# %% [markdown]
# ## Testing Performance

# %%
from sklearn.metrics import confusion_matrix, classification_report 

def confusion_matrix_plot(y_test, y_pred, figsize=(12, 10)):
    plt.figure(figsize=figsize)
    cm = confusion_matrix(y_test, y_pred)
    cm_plot = sns.heatmap(cm, annot=True, fmt='d', cmap="YlGnBu")
    cm_plot.set_title('Confusion Matrix')
    cm_plot.set_xlabel('Predicted Label')
    cm_plot.set_ylabel('True Label')
    plt.show()
    
def classification_report_plot(y_test, y_pred, figsize=(12, 10)):
    plt.figure(figsize=figsize)
    cr = classification_report(y_test, y_pred, output_dict=True)
    cr_heatmap = sns.heatmap(pd.DataFrame(cr).iloc[:-1, :].T, annot=True, cmap="YlGnBu", fmt='.2f')
    cr_heatmap.set_title('Classification Report')
    cr_heatmap.set_xlabel('Metrics')
    cr_heatmap.set_ylabel('Classes')
    plt.show()

# %% [markdown]
# ### Simple Sequential Model

# %%
from tensorflow.keras.models import load_model
model = load_model(f'{MODELS_PATH}/simple_sequential.h5')

# %% [markdown]
# #### Performance Heatmap

# %%
#  confusion matrix and classification report
from sklearn.metrics import accuracy_score

x, y = test_images, test_labels
test_labels_pred = predict_label(x, model)
print("Accuracy:", accuracy_score(y, test_labels_pred))
confusion_matrix_plot(y, test_labels_pred, figsize=(6, 5))
classification_report_plot(y, test_labels_pred, figsize=(6, 5))
# Out:
# 2022-06-09 07:23:36.358773: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Accuracy: 0.7047

# %% [markdown]
# #### Data Visualization

# %%
test_labels
# Out:
# array([158, 112,  49, ...,  27,  26,  26], dtype=uint8)

# %%
rnd_pts = np.random.randint(0, test_images.shape[0], 25)
images = test_images[rnd_pts, :, :]
labels = test_labels[rnd_pts]
labels_pred  = test_labels_pred[rnd_pts]

display_image_grid(images, give_class_name(labels), give_class_name(labels_pred))

# %%
# Plotting only the incorrect images

labels_pred = predict_label(test_images, model)
incorrect_pred = test_labels != labels_pred

rnd_pts = np.random.randint(0, incorrect_pred.sum(), 16)

images = test_images[incorrect_pred, :, :][rnd_pts, :, :]
labels = test_labels[incorrect_pred][rnd_pts]
labels_pred = labels_pred[incorrect_pred][rnd_pts]

display_image_grid(images, give_class_name(labels), give_class_name(labels_pred), shape=(4, 4), figsize=(12, 12))

# %% [markdown]
# ## Results

# %% [markdown]
# ### 70% is not good enough accuracy, Will apply more models untill we get good results

# %% [markdown]
# ### Simple Sequential Model with Dropout

# %%
classification_report_plot(y, test_labels_pred)
