# %% [markdown]
# # VGG Notebook
#
# Contains The Implementation of VGG-Family based Model, through Transfer Learning.

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import os
import pathlib
import sys

# %% [markdown]
# ## Contents

# %% [markdown]
# ### Directories

# %%
# go to parent directory
os.chdir("..")
import paths

REPO_DIR = paths.get_repo_path()
ROOT_DIR = REPO_DIR / "Stanford Dogs"
DATA_BASE_PATH = paths.get_data_path() / "stanford-dogs-dataset"
DATA_PATH = DATA_BASE_PATH / "splited-data"

TRAIN_PATH = DATA_PATH / "train"
TEST_PATH = DATA_PATH / "test"

# set path to repo_dir
os.chdir(REPO_DIR)

# %% [markdown]
# ## Data

# %% [markdown]
# ### Variables

# %%
RANDOM_SEED = 42
IMAGE_WIDTH = 224
IMAGE_HEIGHT = 224

VALIDATION_SPLIT = 0.2

BATCH_SIZE = 32

CLASS_NAMES = sorted([img_cls for img_cls in  os.listdir(TRAIN_PATH) if img_cls != ".DS_Store"])
NUM_CLASSES = len(CLASS_NAMES)

# MODEL
MODEL_PATH = ROOT_DIR / "models"
LOG_PATH = ROOT_DIR / "log"

# %%
tf.random.set_seed(RANDOM_SEED)

# %% [markdown]
# ### Data Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_generator = ImageDataGenerator(
    rescale=1./255,
    
    horizontal_flip=True,
    
    rotation_range=20,
    
    height_shift_range=0.1,       # No need to shift the image
    width_shift_range=0.1,
    zoom_range=0.1,
    
    shear_range=0.1,              # Seems to be useful
    
    validation_split=VALIDATION_SPLIT,
)

val_generator = ImageDataGenerator(
    rescale=1./255,
    validation_split=VALIDATION_SPLIT,
    )

test_generator = ImageDataGenerator(
    rescale=1./255,
)

# %%
train_images = train_generator.flow_from_directory(
    TRAIN_PATH,
    target_size=(IMAGE_WIDTH, IMAGE_HEIGHT),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    
    shuffle=True,
    seed=42,
    
    subset='training',
)

val_images = val_generator.flow_from_directory(
    TRAIN_PATH,
    target_size=(IMAGE_WIDTH, IMAGE_HEIGHT),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    
    shuffle=True,
    seed=42,
    
    subset='validation'
)


test_images = test_generator.flow_from_directory(
    TEST_PATH,
    target_size=(IMAGE_WIDTH, IMAGE_HEIGHT),
    color_mode='rgb',
    class_mode='categorical',
    
    batch_size=BATCH_SIZE,
    
    shuffle=False,
    seed=42,
)

NUM_TRAIN_IMAGES = len(train_images.filenames)
NUM_VAL_IMAGES = len(val_images.filenames)
NUM_TEST_IMAGES = len(test_images.filenames)
# Out:
# Found 12369 images belonging to 120 classes.
# Found 3025 images belonging to 120 classes.
# Found 5186 images belonging to 120 classes.

# %% [markdown]
# ### LOADING DATA

# %%
from sklearn.preprocessing import LabelEncoder

def give_class_name(y:np.ndarray) -> np.ndarray:
    if len(y.shape) == 2:
        y = y.argmax(axis=1)
    enc = LabelEncoder().fit(CLASS_NAMES)
    y_labeled = enc.inverse_transform(y)
    
    return y_labeled

# display images in a grid function
def display_image_grid(images, labels, pred_val=None,shape=(5, 5), figsize=(10, 10)):
    plt.figure(figsize=figsize)
    m = shape[0] * shape[1]
    
    if images.shape[0] < m:
        raise ValueError("images.shape[0] must equal shape[0] * shape[1]")
    
    if labels.shape[0] != images.shape[0]:
        raise ValueError("labels.shape[0] must equal images.shape[0]")
    
    if pred_val is not None and pred_val.shape[0] != images.shape[0]:
        raise ValueError("pred_val.shape[0] must equal images.shape[0]")
    
    for i in range(m):
        plt.subplot(shape[0], shape[1], i+1)
        plt.imshow(images[i], cmap="gray", interpolation="none")
        title = labels[i]
        if pred_val is not None:
            title = f"{pred_val[i]}"
            if pred_val[i] != labels[i]:
                title += f"\n*({labels[i]})*"
        plt.title(title)
        plt.axis("off")
        # increase vertical space between subplots
        plt.subplots_adjust(wspace=0.1, hspace=0.4)
    plt.show()

# %%
CLASS_NAMES = list(train_images.class_indices)

CLASS_NAMES[:10]
# Out:
# ['Affenpinscher',
#  'Afghan Hound',
#  'African Hunting Dog',
#  'Airedale',
#  'American Staffordshire Terrier',
#  'Appenzeller',
#  'Australian Terrier',
#  'Basenji',
#  'Basset',
#  'Beagle']

# %%
num_rows = 8
num_cols = 4

plt.figure(figsize=(20, 18))

images, labels = train_images.next()
for i in range(num_cols * num_rows):
    plt.subplot(num_cols, num_rows, i + 1)
    plt.imshow(images[i])
    plt.title(CLASS_NAMES[labels[i].argmax()])
    plt.axis('off')

plt.show()

# %% [markdown]
# ## Model

# %%
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Rescaling, Input, Add, Activation, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, f1_score, precision_score, recall_score

# %% [markdown]
# ### Valribles

# %%
INPUT_SHAPE = train_images.next()[0][0].shape
TRAIN_MODELS = True
# TRAIN_MODELS = False

# %% [markdown]
# ### Useful functions ###

# %%
def predict_label(images, model):
    predictions = model.predict(images)
    return predictions.argmax(axis=1)


# ploting the model training history
def plot_model_performance(history, figsize=(10, 10)):
    preformance = {key: val for key, val in history.history.items() if "loss" not in key}
    losses = {key: val for key, val in history.history.items() if "loss" in key}
    
    plt.figure(figsize=figsize)
    plt.title('Model Performance')
    for key, val in preformance.items():
        plt.plot(val, label=key)
    plt.legend(preformance.keys())
    plt.xlabel('Epoch')
    
    plt.figure(figsize=figsize)
    plt.title('Model Losses')
    for key, val in losses.items():
        plt.plot(val, label=key)
    plt.legend(losses.keys())
    plt.xlabel('Epoch')
    
    plt.show()


def get_model_performance(y_true, y_pred):
    if len(y_true.shape) == 2:
        y_true = y_true.argmax(axis=1)
    if len(y_pred.shape) == 2:
        y_pred = y_pred.argmax(axis=1)

    accuracy = accuracy_score(y_true, y_pred)
    f1_scr = f1_score(y_true, y_pred, average='weighted')
    precision_scr = precision_score(y_true, y_pred, average='weighted')
    recall_scr = recall_score(y_true, y_pred, average='weighted')
    
    performance = {
        "Accuracy": accuracy,
        "F1 Score": f1_scr,
        "Precision": precision_scr,
        "Recall": recall_scr
    }
    
    return performance

# %% [markdown]
# ### MODELS

# %% [markdown]
# #### MODEL ARCHITECTURE

# %%
from tensorflow.keras.models import Sequential

model_name = "TL-VGG-19"
weight_decay = 10e-5
LEARNING_RATE = 1e-3
# weight_decay = 0

def final_model(tl_model, num_classes: int):
    model = Sequential(name=model_name)
    
    tl_model.trainable = False
    model.add(tl_model)
    model.add(GlobalAveragePooling2D())
    
    model.add(Dropout(0.3))
    
    model.add(Dense(512, kernel_regularizer=l2(weight_decay)))
    model.add(BatchNormalization())
    model.add(Activation("relu"))
    
    model.add(Dropout(0.4))
    
    model.add(Dense(num_classes, activation='softmax'))
    
    return model

# %%
# 
from tensorflow.keras.applications.vgg19 import VGG19

tl_model = VGG19(weights='imagenet', include_top=False, input_shape=INPUT_SHAPE)

print("Total Params:", tl_model.count_params())
# Out:
# 2022-07-11 04:00:28.006148: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 04:00:28.026048: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 04:00:28.026199: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# Total Params: 20024384
# 2022-07-11 04:00:28.026936: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-11 04:00:28.027268: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 04:00:28.027373: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 04:00:28.027454: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 04:00:28.348627: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 04:00:28.348770: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 04:00:28.348861: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 04:00:28.348935: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6016 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
model = final_model(tl_model, num_classes=NUM_CLASSES)

model.compile(
        optimizer=Adam(learning_rate=LEARNING_RATE), 
        loss='categorical_crossentropy', 
        metrics=[
            'accuracy',
            'top_k_categorical_accuracy',
            ]
        )
model.summary()
# Out:
# Model: "TL-VGG-19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 512)               262656
#
#  batch_normalization (BatchN  (None, 512)              2048
#  ormalization)
#
#  activation (Activation)     (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 120)               61560
#
# =================================================================
# Total params: 20,350,648
# Trainable params: 325,240
# Non-trainable params: 20,025,408
# _________________________________________________________________

# %% [markdown]
# #### Model Training

# %%
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint, CSVLogger

monitor_metric = 'val_accuracy'

# Early stopping
es = EarlyStopping(
        monitor=monitor_metric,
        patience=5,
        mode = "auto",
        verbose=1,
)

# Learning rate scheduler
def step_decay(epoch):
    initial_lr = LEARNING_RATE
    k = 0.1
    lr = initial_lr * np.exp(-k*epoch)
    return lr

lrd = LearningRateScheduler(step_decay)

# Model Checkpoint
mdl_check = ModelCheckpoint(
        MODEL_PATH / f"{model_name}.h5",
        monitor=monitor_metric,
        save_best_only=True,
        mode='auto',
        verbose=1,
)
        
# CSV Logger
csv_logger = CSVLogger(
        LOG_PATH / f"{model_name}.csv",
        append=False,
)


callbacks = [
        es, 
        lrd,
        mdl_check, 
        # csv_logger,
    ]

# %%
from tensorflow.keras.models import load_model

train_model = not (os.path.exists(MODEL_PATH / f"{model_name}.h5")) or TRAIN_MODELS

if train_model:
    history = model.fit(train_images, 
                        validation_data=val_images,
                        epochs=50, 
                        callbacks=callbacks,                        
)
else:
    model_path = MODEL_PATH / f"{model_name}.h5"
    model = load_model(model_path)
    print(f"{model_name} model loaded from {model_path}")
# Out:
# Epoch 1/50
# 2022-07-11 04:00:29.963524: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8201
# 2022-07-11 04:00:30.576916: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-07-11 04:00:30.577464: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-07-11 04:00:30.577483: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2022-07-11 04:00:30.578033: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-07-11 04:00:30.578074: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
#   2/387 [..............................] - ETA: 29s - loss: 5.6315 - accuracy: 0.0000e+00 - top_k_categorical_accuracy: 0.0625
# 2022-07-11 04:00:31.576792: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 387/387 [==============================] - ETA: 0s - loss: 5.0750 - accuracy: 0.0175 - top_k_categorical_accuracy: 0.0748
# Epoch 1: val_accuracy improved from -inf to 0.08694, saving model to /home/vineet/.personal/code/Hello-CNN/Stanford Dogs/models/TL-VGG-19.h5
# 387/387 [==============================] - 73s 183ms/step - loss: 5.0750 - accuracy: 0.0175 - top_k_categorical_accuracy: 0.0748 - val_loss: 4.3726 - val_accuracy: 0.0869 - val_top_k_categorical_accuracy: 0.2420 - lr: 0.0010
# Epoch 2/50
# 387/387 [==============================] - ETA: 0s - loss: 4.5902 - accuracy: 0.0441 - top_k_categorical_accuracy: 0.1597
# Epoch 2: val_accuracy improved from 0.08694 to 0.12066, saving model to /home/vineet/.personal/code/Hello-CNN/Stanford Dogs/models/TL-VGG-19.h5
# 387/387 [==============================] - 72s 185ms/step - loss: 4.5902 - accuracy: 0.0441 - top_k_categorical_accuracy: 0.1597 - val_loss: 4.0350 - val_accuracy: 0.1207 - val_top_k_categorical_accuracy: 0.3415 - lr: 9.0484e-04
# Epoch 3/50
# 387/387 [==============================] - ETA: 0s - loss: 4.3121 - accuracy: 0.0704 - top_k_categorical_accuracy: 0.2312
# Epoch 3: val_accuracy improved from 0.12066 to 0.15008, saving model to /home/vineet/.personal/code/Hello-CNN/Stanford Dogs/models/TL-VGG-19.h5
# 387/387 [==============================] - 70s 182ms/step - loss: 4.3121 - accuracy: 0.0704 - top_k_categorical_accuracy: 0.2312 - val_loss: 3.8530 - val_accuracy: 0.1501 - val_top_k_categorical_accuracy: 0.3997 - lr: 8.1873e-04
# Epoch 4/50
# 387/387 [==============================] - ETA: 0s - loss: 4.1769 - accuracy: 0.0855 - top_k_categorical_accuracy: 0.2678
# Epoch 4: val_accuracy improved from 0.15008 to 0.16231, saving model to /home/vineet/.personal/code/Hello-CNN/Stanford Dogs/models/TL-VGG-19.h5
# 387/387 [==============================] - 71s
saving model to /home/vineet/.personal/code/Hello-CNN/Stanford Dogs/models/TL-VGG-19.h5
# 387/387 [==============================] - 71s 182ms/step - loss: 3.6438 - accuracy: 0.1686 - top_k_categorical_accuracy: 0.4145 - val_loss: 3.2979 - val_accuracy: 0.2390 - val_top_k_categorical_accuracy: 0.5336 - lr: 1.6530e-04
# Epoch 20/50
# 387/387 [==============================] - ETA: 0s - loss: 3.6342 - accuracy: 0.1702 - top_k_categorical_accuracy: 0.4207
# Epoch 20: val_accuracy improved from 0.23901 to 0.24099, saving model to /home/vineet/.personal/code/Hello-CNN/Stanford Dogs/models/TL-VGG-19.h5
# 387/387 [==============================] - 71s 182ms/step - loss: 3.6342 - accuracy: 0.1702 - top_k_categorical_accuracy: 0.4207 - val_loss: 3.2913 - val_accuracy: 0.2410 - val_top_k_categorical_accuracy: 0.5349 - lr: 1.4957e-04
# Epoch 21/50
# 387/387 [==============================] - ETA: 0s - loss: 3.6085 - accuracy: 0.1757 - top_k_categorical_accuracy: 0.4324
# Epoch 21: val_accuracy improved from 0.24099 to 0.24331, saving model to /home/vineet/.personal/code/Hello-CNN/Stanford Dogs/models/TL-VGG-19.h5
# 387/387 [==============================] - 70s 182ms/step - loss: 3.6085 - accuracy: 0.1757 - top_k_categorical_accuracy: 0.4324 - val_loss: 3.2779 - val_accuracy: 0.2433 - val_top_k_categorical_accuracy: 0.5392 - lr: 1.3534e-04
# Epoch 22/50
# 387/387 [==============================] - ETA: 0s - loss: 3.5908 - accuracy: 0.1785 - top_k_categorical_accuracy: 0.4352
# Epoch 22: val_accuracy did not improve from 0.24331
# 387/387 [==============================] - 71s 184ms/step - loss: 3.5908 - accuracy: 0.1785 - top_k_categorical_accuracy: 0.4352 - val_loss: 3.2766 - val_accuracy: 0.2430 - val_top_k_categorical_accuracy: 0.5345 - lr: 1.2246e-04
# Epoch 23/50
# 387/387 [==============================] - ETA: 0s - loss: 3.5857 - accuracy: 0.1784 - top_k_categorical_accuracy: 0.4346
# Epoch 23: val_accuracy did not improve from 0.24331
# 387/387 [==============================] - 70s 181ms/step - loss: 3.5857 - accuracy: 0.1784 - top_k_categorical_accuracy: 0.4346 - val_loss: 3.2752 - val_accuracy: 0.2423 - val_top_k_categorical_accuracy: 0.5379 - lr: 1.1080e-04
# Epoch 24/50
# 387/387 [==============================] - ETA: 0s - loss: 3.5778 - accuracy: 0.1826 - top_k_categorical_accuracy: 0.4375
# Epoch 24: val_accuracy did not improve from 0.24331
# 387/387 [==============================] - 71s 183ms/step - loss: 3.5778 - accuracy: 0.1826 - top_k_categorical_accuracy: 0.4375 - val_loss: 3.2718 - val_accuracy: 0.2423 - val_top_k_categorical_accuracy: 0.5372 - lr: 1.0026e-04
# Epoch 25/50
# 387/387 [==============================] - ETA: 0s - loss: 3.6084 - accuracy: 0.1766 - top_k_categorical_accuracy: 0.4337
# Epoch 25: val_accuracy improved from 0.24331 to 0.24397, saving model to /home/vineet/.personal/code/Hello-CNN/Stanford Dogs/models/TL-VGG-19.h5
# 387/387 [==============================] - 72s 185ms/step - loss: 3.6084 - accuracy: 0.1766 - top_k_categorical_accuracy: 0.4337 - val_loss: 3.2644 - val_accuracy: 0.2440 - val_top_k_categorical_accuracy: 0.5359 - lr: 9.0718e-05
# Epoch 26/50
# 387/387 [==============================] - ETA: 0s - loss: 3.5717 - accuracy: 0.1823 - top_k_categorical_accuracy: 0.4383
# Epoch 26: val_accuracy improved from 0.24397 to 0.24727, saving model to /home/vineet/.personal/code/Hello-CNN/Stanford Dogs/models/TL-VGG-19.h5
# 387/387 [==============================] - 71s 182ms/step - loss: 3.5717 - accuracy: 0.1823 - top_k_categorical_accuracy: 0.4383 - val_loss: 3.2597 - val_accuracy: 0.2473 - val_top_k_categorical_accuracy: 0.5385 - lr: 8.2085e-05
# Epoch 27/50
# 387/387 [==============================] - ETA: 0s - loss: 3.5708 - accuracy: 0.1859 - top_k_categorical_accuracy: 0.4330
# Epoch 27: val_accuracy did not improve from 0.24727
# 387/387 [==============================] - 70s 182ms/step - loss: 3.5708 - accuracy: 0.1859 - top_k_categorical_accuracy: 0.4330 - val_loss: 3.2594 - val_accuracy: 0.2446 - val_top_k_categorical_accuracy: 0.5359 - lr: 7.4274e-05
# Epoch 28/50
# 387/387 [==============================] - ETA: 0s - loss: 3.5571 - accuracy: 0.1831 - top_k_categorical_accuracy: 0.4388
# Epoch 28: val_accuracy improved from 0.24727 to 0.24893, saving model to /home/vineet/.personal/code/Hello-CNN/Stanford Dogs/models/TL-VGG-19.h5
# 387/387 [==============================] - 71s 182ms/step - loss: 3.5571 - accuracy: 0.1831 - top_k_categorical_accuracy: 0.4388 - val_loss: 3.2582 - val_accuracy: 0.2489 - val_top_k_categorical_accuracy: 0.5395 - lr: 6.7206e-05
# Epoch 29/50
# 387/387 [==============================] - ETA: 0s - loss: 3.5782 - accuracy: 0.1807 - top_k_categorical_accuracy: 0.4389
# Epoch 29: val_accuracy improved from 0.24893 to 0.24959, saving model to /home/vineet/.personal/code/Hello-CNN/Stanford Dogs/models/TL-VGG-19.h5
# 387/387 [==============================] - 71s 183ms/step - loss: 3.5782 - accuracy: 0.1807 - top_k_categorical_accuracy: 0.4389 - val_loss: 3.2546 - val_accuracy: 0.2496 - val_top_k_categorical_accuracy: 0.5398 - lr: 6.0810e-05
# Epoch 30/50
# 387/387 [==============================] - ETA: 0s - loss: 3.5478 - accuracy: 0.1886 - top_k_categorical_accuracy: 0.4441
# Epoch 30: val_accuracy improved from 0.24959 to 0.25091, saving model to /home/vineet/.personal/code/Hello-CNN/Stanford Dogs/models/TL-VGG-19.h5
# 387/387 [==============================] - 70s 181ms/step - loss: 3.5478 - accuracy: 0.1886 - top_k_categorical_accuracy: 0.4441 - val_loss: 3.2519 - val_accuracy: 0.2509 - val_top_k_categorical_accuracy: 0.5365 - lr: 5.5023e-05
# Epoch 31/50
# 387/387 [==============================] - ETA: 0s - loss: 3.5585 - accuracy: 0.1832 - top_k_categorical_accuracy: 0.4444
# Epoch 31: val_accuracy did not improve from 0.25091
# 387/387 [==============================] - 71s 184ms/step - loss: 3.5585 - accuracy: 0.1832 - top_k_categorical_accuracy: 0.4444 - val_loss: 3.2468 - val_accuracy: 0.2486 - val_top_k_categorical_accuracy: 0.5398 - lr: 4.9787e-05
# Epoch 32/50
# 387/387 [==============================] - ETA: 0s - loss: 3.5285 - accuracy: 0.1844 - top_k_categorical_accuracy: 0.4502
# Epoch 32: val_accuracy did not improve from 0.25091
# 387/387 [==============================] - 71s 184ms/step - loss: 3.5285 - accuracy: 0.1844 - top_k_categorical_accuracy: 0.4502 - val_loss: 3.2437 - val_accuracy: 0.2502 - val_top_k_categorical_accuracy: 0.5415 - lr: 4.5049e-05
# Epoch 33/50
# 387/387 [==============================] - ETA: 0s - loss: 3.5478 - accuracy: 0.1872 - top_k_categorical_accuracy: 0.4400
# Epoch 33: val_accuracy did not improve from 0.25091
# 387/387 [==============================] - 70s 181ms/step - loss: 3.5478 - accuracy: 0.1872 - top_k_categorical_accuracy: 0.4400 - val_loss: 3.2450 - val_accuracy: 0.2476 - val_top_k_categorical_accuracy: 0.5421 - lr: 4.0762e-05
# Epoch 34/50
# 387/387 [==============================] - ETA: 0s - loss: 3.5410 - accuracy: 0.1914 - top_k_categorical_accuracy: 0.4480
# Epoch 34: val_accuracy did not improve from 0.25091
# 387/387 [==============================] - 72s 185ms/step - loss: 3.5410 - accuracy: 0.1914 - top_k_categorical_accuracy: 0.4480 - val_loss: 3.2400 - val_accuracy: 0.2496 - val_top_k_categorical_accuracy: 0.5418 - lr: 3.6883e-05
# Epoch 35/50
# 387/387 [==============================] - ETA: 0s - loss: 3.5465 - accuracy: 0.1859 - top_k_categorical_accuracy: 0.4496
# Epoch 35: val_accuracy did not improve from 0.25091
# 387/387 [==============================] - 70s 181ms/step - loss: 3.5465 - accuracy: 0.1859 - top_k_categorical_accuracy: 0.4496 - val_loss: 3.2392 - val_accuracy: 0.2479 - val_top_k_categorical_accuracy: 0.5421 - lr: 3.3373e-05
# Epoch 35: early stopping

# %%
if train_model:
    plot_model_performance(history)

# %%
if train_model:
    model.evaluate(test_images)
# Out:
# 163/163 [==============================] - 13s 79ms/step - loss: 3.1917 - accuracy: 0.2599 - top_k_categorical_accuracy: 0.5538

# %%
test_images.shuffle = False
test_images.batch_size = 7

test_labels = test_images.labels
test_labels_pred_ohe = model.predict(test_images)
test_labels_pred = test_labels_pred_ohe.argmax(axis=1)

# %%
plt_size = (20, 18)

test_images.shuffle = True

num_rows = 6
num_cols = 4

test_images.batch_size = num_rows * num_cols

images, labels = test_images.next()
labels_pred = predict_label(images, model)

display_image_grid(
                images, 
                give_class_name(labels), give_class_name(labels_pred),
                shape=(num_rows, num_cols),
                figsize=plt_size,
                )

# %%
#  confusion matrix and classification report

performance = get_model_performance(test_labels, test_labels_pred)
print(classification_report(test_labels, test_labels_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.24      0.42      0.30        38
#            1       0.27      0.67      0.38        60
#            2       0.37      0.72      0.49        43
#            3       0.19      0.16      0.17        51
#            4       0.19      0.07      0.11        41
#            5       0.15      0.13      0.14        38
#            6       0.31      0.33      0.32        49
#            7       0.19      0.38      0.25        53
#            8       0.28      0.45      0.35        44
#            9       0.18      0.22      0.20        49
#           10       0.31      0.37      0.34        46
#           11       0.23      0.18      0.20        55
#           12       0.24      0.25      0.25        40
#           13       0.59      0.64      0.61        47
#           14       0.24      0.19      0.21        47
#           15       0.33      0.33      0.33        43
#           16       0.25      0.13      0.17        38
#           17       0.32      0.21      0.25        43
#           18       0.14      0.05      0.08        38
#           19       0.29      0.37      0.32        46
#           20       0.31      0.34      0.33        38
#           21       0.19      0.08      0.11        38
#           22       0.26      0.15      0.19        39
#           23       0.17      0.03      0.05        38
#           24       0.00      0.00      0.00        38
#           25       0.32      0.23      0.27        39
#           26       0.15      0.14      0.15        50
#           27       0.44      0.10      0.17        39
#           28       0.17      0.10      0.12        42
#           29       0.22      0.16      0.18        38
#           30       0.25      0.18      0.21        49
#           31       0.34      0.34      0.34        38
#           32       0.18      0.12      0.15        40
#           33       0.17      0.03      0.04        39
#           34       0.21      0.37      0.27        38
#           35       0.35      0.38      0.36        45
#           36       0.20      0.61      0.30        38
#           37       0.24      0.36      0.29        39
#           38       0.06      0.03      0.04        38
#           39       0.17      0.38      0.23        40
#           40       0.24      0.17      0.20        41
#           41       0.20      0.10      0.13        40
#           42       0.27      0.49      0.34        51
#           43       0.18      0.11      0.13        38
#           44       0.06      0.08      0.07        38
#           45       0.42      0.35      0.38        40
#           46       0.27      0.16      0.20        38
#           47       0.27      0.24      0.25        38
#           48       0.54      0.17      0.26        40
#           49       0.33      0.39      0.36        38
#           50       0.03      0.03      0.03        39
#           51       0.22      0.05      0.08        39
#           52       0.04      0.02      0.03        54
#           53       0.19      0.14      0.16        42
#           54       0.34      0.47      0.40        38
#           55       0.25      0.34      0.29        47
#           56       0.20      0.05      0.08        39
#           57       0.40      0.14      0.21        43
#           58       0.22      0.39      0.29        38
#           59       0.00      0.00      0.00        55
#           60       0.08      0.07      0.07        46
#           61       0.37      0.51      0.43        47
#           62       0.31      0.38      0.34        40
#           63       0.23      0.26      0.24        39
#           64       0.25      0.49      0.33        45
#           65       0.39      0.59      0.47        39
#           66       0.26      0.29      0.28        38
#           67       0.21      0.30      0.25        43
#           68       0.05      0.02      0.03        50
#           69       0.37      0.60      0.46        53
#           70       0.35      0.19      0.25        47
#           71       0.33      0.18      0.23        45
#           72       0.33      0.08      0.13        38
#           73       0.23      0.38      0.29        63
#           74       0.28      0.51      0.36        39
#           75       0.23      0.30      0.26        46
#           76       0.11      0.08      0.09        39
#           77       0.26      0.21      0.23        39
#           78       0.18      0.27      0.21        49
#           79       0.36      0.21      0.26        43
#           80       0.37      0.35      0.36        49
#           81       0.29      0.21      0.25        47
#           82       0.36      0.09      0.15        43
#           83       0.32      0.42      0.36        38
#           84       0.33      0.37      0.35        49
#           85       0.12      0.03      0.04        38
#           86       0.37      0.22      0.27        46
#           87       0.30      0.45      0.36        55
#           88       0.29      0.22      0.25        50
#           89       0.22      0.24      0.23        37
#           90       0.23      0.21      0.22        43
#           91       0.31      0.21      0.25        38
#           92       0.37      0.47      0.41        43
#           93       0.22      0.32      0.26        50
#           94       0.21      0.56      0.31        55
#           95       0.30      0.56      0.39        39
#           96       0.40      0.35      0.37        40
#           97       0.26      0.36      0.30        58
#           98       0.49      0.47      0.48        51
#           99       0.29      0.17      0.22        40
#          100       0.21      0.07      0.11        54
#          101       0.35      0.31      0.33        48
#          102       0.57      0.50      0.53        46
#          103       0.05      0.03      0.03        39
#          104       0.36      0.23      0.28        39
#          105       0.00      0.00      0.00        40
#          106       0.11      0.05      0.07        39
#          107       0.23      0.37      0.28        38
#          108       0.30      0.18      0.23        38
#          109       0.17      0.21      0.19        52
#          110       0.04      0.03      0.03        38
#          111       0.32      0.28      0.30        43
#          112       0.19      0.10      0.13        39
#          113       0.40      0.21      0.27        39
#          114       0.22      0.25      0.24        40
#          115       0.10      0.08      0.09        38
#          116       0.44      0.42      0.43        43
#          117       0.13      0.26      0.17        47
#          118       0.28      0.23      0.25        40
#          119       0.19      0.20      0.19        41
#
#     accuracy                           0.26      5186
#    macro avg       0.25      0.25      0.24      5186
# weighted avg       0.25      0.26      0.24      5186

# %%
# top 5 accuracy and classification report
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.metrics import top_k_categorical_accuracy

test_labels_ohe = tf.keras.utils.to_categorical (test_labels)
top_5_accuracy = top_k_categorical_accuracy(test_labels_ohe, test_labels_pred_ohe, k=5)

top_5_accuracy = top_5_accuracy.numpy().sum() / len(test_labels)

print(f"Top 1 Accuracy: {100* performance['Accuracy']:.2f}%")
print(f"Top 5 Accuracy: {top_5_accuracy:.2%}")
# Out:
# Top 1 Accuracy: 25.99%
# Top 5 Accuracy: 55.36%
