# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import os
import pathlib
import sys

# %%
# go to parent directory
os.chdir("..")
import paths

REPO_DIR = paths.get_repo_path()
ROOT_DIR = REPO_DIR / "CIFAR-10"

# set path to repo_dir
os.chdir(REPO_DIR)

# %% [markdown]
# ## Data

# %%
CLASS_NAMES = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]
NUM_CLASSES = len(CLASS_NAMES)

# %%
from sklearn.preprocessing import LabelEncoder

def give_class_name(y:np.ndarray) -> np.ndarray:
    enc = LabelEncoder().fit(CLASS_NAMES)
    y_labeled = enc.inverse_transform(y)
    
    return y_labeled

# %% [markdown]
# ### Load CIFAR-10 data

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.cifar10.load_data()

# Image scaling to 0-1
# train_images = train_images / 255.0
# test_images = test_images / 255.0

if train_labels.ndim == 2:
    train_labels = train_labels.flatten()
    test_labels = test_labels.flatten()


total_data = f"Total Data on RAM -{(train_images.size + test_images.size) / 1024**2 : .2f} MB"
total_data
# Out:
# 'Total Data on RAM - 175.78 MB'

# %% [markdown]
# ### Displaying the first image in the training set

# %%
# display images in a grid function
def display_image_grid(images, labels, pred_val=None,shape=(5, 5), figsize=(10, 10)):
    plt.figure(figsize=figsize)
    m = shape[0] * shape[1]
    
    if images.shape[0] < m:
        raise ValueError("images.shape[0] must equal shape[0] * shape[1]")
    
    if labels.shape[0] != images.shape[0]:
        raise ValueError("labels.shape[0] must equal images.shape[0]")
    
    if pred_val is not None and pred_val.shape[0] != images.shape[0]:
        raise ValueError("pred_val.shape[0] must equal images.shape[0]")
    
    for i in range(m):
        plt.subplot(shape[0], shape[1], i+1)
        plt.imshow(images[i], cmap="gray", interpolation="none")
        title = labels[i]
        if pred_val is not None:
            title = f"{pred_val[i]}"
            if pred_val[i] != labels[i]:
                title += f"(incorrect, {labels[i]})"
        plt.title(title)
        plt.axis("off")
    plt.show()

# %%
# display 25 random images from the training set
rnd_pts = np.random.randint(0, train_images.shape[0], 25)
images = train_images[rnd_pts, :, :]
labels = train_labels[rnd_pts]

display_image_grid(images, give_class_name(labels))

# %% [markdown]
# ### Preprocessing the data

# %%
# One hot encode the labels
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(train_labels)
y_test = to_categorical(test_labels)

# %% [markdown]
# ## MODELS

# %%
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Normalization, Rescaling

# %%
MODELS_PATH = ROOT_DIR / "models"
INPUT_SHAPE = train_images.shape[1:]

# %%
def predict_label(images, model):
    predictions = model.predict(images)
    return predictions.argmax(axis=1)

# %% [markdown]
# ### Create Models
#
# TODO List -
#    - Improve Simple Sequential Model
#      - Read and see other Models
#    - Add more Models
#      - Model with VGG-Like Blocks
#      - Model with residual Blocks
#      - Model With Inseption Blocks
#      - Model With Mobile Blocks
#      - Transfer Learning Models
#        - VGG
#        - ResNet
#        - Inseption
#        - Mobile

# %% [markdown]
# #### Simple Sequential Model

# %%
from tensorflow.keras.models import Sequential

def simple_sequential_model(input_shape, num_classes):
    model = Sequential()
    
    model.add(Rescaling(1./255, input_shape=input_shape))
    
    model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', padding="same"))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Normalization())
    
    model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding="same"))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Normalization())
    
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.25))
    model.add(Dense(10, activation='softmax'))
    
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %% [markdown]
# #### Deeper Sequential Model

# %%
from tensorflow.keras.models import Sequential

def deeper_sequential_model(input_shape, num_classes):
    model = Sequential()
    
    model.add(Rescaling(1./255, input_shape=input_shape))
    
    model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding="same"))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Normalization())
    
    model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding="same"))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Normalization())
    
    model.add(Conv2D(256, kernel_size=(3, 3), activation='relu', padding="same"))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Normalization())
    
    model.add(Flatten())
    model.add(Dropout(0.3))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(32, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(10, activation='softmax'))
    
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %% [markdown]
# ### Training

# %%
# ploting the model training history

def plot_model_performance(history, figsize=(10, 10)):
    preformance = {key: val for key, val in history.history.items() if "loss" not in key}
    losses = {key: val for key, val in history.history.items() if "loss" in key}
    
    plt.figure(figsize=figsize)
    plt.title('Model Performance')
    for key, val in preformance.items():
        plt.plot(val, label=key)
    plt.legend(preformance.keys())
    plt.xlabel('Epoch')
    
    plt.figure(figsize=figsize)
    plt.title('Model Losses')
    for key, val in losses.items():
        plt.plot(val, label=key)
    plt.legend(losses.keys())
    plt.xlabel('Epoch')
    
    plt.show()

# %% [markdown]
# #### Simple Sequential Model

# %%
model = simple_sequential_model(INPUT_SHAPE, NUM_CLASSES)
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_8 (Rescaling)     (None, 32, 32, 3)         0
#
#  conv2d_31 (Conv2D)          (None, 32, 32, 32)        896
#
#  max_pooling2d_31 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  normalization_31 (Normaliza  (None, 16, 16, 32)       65
#  tion)
#
#  conv2d_32 (Conv2D)          (None, 16, 16, 64)        18496
#
#  max_pooling2d_32 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  normalization_32 (Normaliza  (None, 8, 8, 64)         129
#  tion)
#
#  flatten_8 (Flatten)         (None, 4096)              0
#
#  dense_25 (Dense)            (None, 256)               1048832
#
#  dropout_17 (Dropout)        (None, 256)               0
#
#  dense_26 (Dense)            (None, 64)                16448
#
#  dropout_18 (Dropout)        (None, 64)                0
#
#  dense_27 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 1,085,516
# Trainable params: 1,085,322
# Non-trainable params: 194
# _________________________________________________________________

# %%
# callbacks
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint

# Early stopping
es = EarlyStopping(monitor='val_accuracy', verbose=1, patience=5, mode='max')
# learning rate scheduler
lrd = LearningRateScheduler(lambda epoch: 1 / 10**(3 + epoch // 6))
# model checkpoint
mdl_check = ModelCheckpoint(filepath=f'{MODELS_PATH}/simple_sequential.h5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

callbacks = [es, mdl_check]

# %%
history = model.fit(train_images, y_train, 
                    epochs=30, batch_size=64,
                    validation_split=0.2, callbacks=callbacks)
# Out:
# Epoch 1/30
#   1/625 [..............................] - ETA: 6:47 - loss: 2.3703 - accuracy: 0.0312
# 2022-06-12 13:58:47.800829: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 623/625 [============================>.] - ETA: 0s - loss: 1.6181 - accuracy: 0.4049
# 2022-06-12 13:58:57.367211: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_accuracy improved from -inf to 0.54990, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 11s 17ms/step - loss: 1.6166 - accuracy: 0.4058 - val_loss: 1.2823 - val_accuracy: 0.5499
# Epoch 2/30
# 623/625 [============================>.] - ETA: 0s - loss: 1.1956 - accuracy: 0.5744
# Epoch 2: val_accuracy improved from 0.54990 to 0.62510, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 10s 17ms/step - loss: 1.1955 - accuracy: 0.5744 - val_loss: 1.0613 - val_accuracy: 0.6251
# Epoch 3/30
# 624/625 [============================>.] - ETA: 0s - loss: 1.0111 - accuracy: 0.6448
# Epoch 3: val_accuracy improved from 0.62510 to 0.63500, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 10s 17ms/step - loss: 1.0115 - accuracy: 0.6448 - val_loss: 1.0399 - val_accuracy: 0.6350
# Epoch 4/30
# 624/625 [============================>.] - ETA: 0s - loss: 0.9016 - accuracy: 0.6844
# Epoch 4: val_accuracy improved from 0.63500 to 0.67430, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 10s 17ms/step - loss: 0.9014 - accuracy: 0.6845 - val_loss: 0.9367 - val_accuracy: 0.6743
# Epoch 5/30
# 625/625 [==============================] - ETA: 0s - loss: 0.8059 - accuracy: 0.7184
# Epoch 5: val_accuracy improved from 0.67430 to 0.69640, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 10s 16ms/step - loss: 0.8059 - accuracy: 0.7184 - val_loss: 0.8733 - val_accuracy: 0.6964
# Epoch 6/30
# 624/625 [============================>.] - ETA: 0s - loss: 0.7364 - accuracy: 0.7427
# Epoch 6: val_accuracy improved from 0.69640 to 0.69820, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 10s 16ms/step - loss: 0.7364 - accuracy: 0.7427 - val_loss: 0.8892 - val_accuracy: 0.6982
# Epoch 7/30
# 624/625 [============================>.] - ETA: 0s - loss: 0.6660 - accuracy: 0.7672
# Epoch 7: val_accuracy improved from 0.69820 to 0.71770, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 12s 18ms/step - loss: 0.6659 - accuracy: 0.7672 - val_loss: 0.8352 - val_accuracy: 0.7177
# Epoch 8/30
# 622/625 [============================>.] - ETA: 0s - loss: 0.6022 - accuracy: 0.7881
# Epoch 8: val_accuracy improved from 0.71770 to 0.72440, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 10s 16ms/step - loss: 0.6021 - accuracy: 0.7882 - val_loss: 0.8326 - val_accuracy: 0.7244
# Epoch 9/30
# 623/625 [============================>.] - ETA: 0s - loss: 0.5473 - accuracy: 0.8086
# Epoch 9: val_accuracy did not improve from 0.72440
# 625/625 [==============================] - 10s 16ms/step - loss: 0.5473 - accuracy: 0.8087 - val_loss: 0.8407 - val_accuracy: 0.7202
# Epoch 10/30
# 623/625 [============================>.] - ETA: 0s - loss: 0.4944 - accuracy: 0.8279
# Epoch 10: val_accuracy did not improve from 0.72440
# 625/625 [==============================] - 10s 16ms/step - loss: 0.4947 - accuracy: 0.8279 - val_loss: 0.8894 - val_accuracy: 0.7207
# Epoch 11/30
# 624/625 [============================>.] - ETA: 0s - loss: 0.4433 - accuracy: 0.8443
# Epoch 11: val_accuracy improved from 0.72440 to 0.72600, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 10s 16ms/step - loss: 0.4433 - accuracy: 0.8443 - val_loss: 0.8994 - val_accuracy: 0.7260
# Epoch 12/30
# 623/625 [============================>.] - ETA: 0s - loss: 0.3991 - accuracy: 0.8592
# Epoch 12: val_accuracy did not improve from 0.72600
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3991 - accuracy: 0.8592 - val_loss: 0.9362 - val_accuracy: 0.7232
# Epoch 13/30
# 624/625 [============================>.] - ETA: 0s - loss: 0.3582 - accuracy: 0.8733
# Epoch 13: val_accuracy did not improve from 0.72600
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3585 - accuracy: 0.8733 - val_loss: 0.9824 - val_accuracy: 0.7232
# Epoch 14/30
# 622/625 [============================>.] - ETA: 0s - loss: 0.3267 - accuracy: 0.8852
# Epoch 14: val_accuracy did not improve from 0.72600
# 625/625 [==============================] - 10s 16ms/step - loss: 0.3270 - accuracy: 0.8851 - val_loss: 1.0204 - val_accuracy: 0.7211
# Epoch 15/30
# 624/625 [============================>.] - ETA: 0s - loss: 0.3000 - accuracy: 0.8935
# Epoch 15: val_accuracy did not improve from 0.72600
# 625/625 [==============================] - 10s 16ms/step - loss: 0.2998 - accuracy: 0.8935 - val_loss: 1.0383 - val_accuracy: 0.7216
# Epoch 16/30
# 625/625 [==============================] - ETA: 0s - loss: 0.2739 - accuracy: 0.9036
# Epoch 16: val_accuracy did not improve from 0.72600
# 625/625 [==============================] - 10s 17ms/step - loss: 0.2739 - accuracy: 0.9036 - val_loss: 1.0941 - val_accuracy: 0.7234
# Epoch 16: early stopping

# %%
plot_model_performance(history)

# %%
model.evaluate(test_images, y_test)
# Out:
# 313/313 [==============================] - 4s 13ms/step - loss: 1.1947 - accuracy: 0.7536
# [1.1946688890457153, 0.7536000609397888]

# %% [markdown]
# #### Deeper Sequential Model

# %%
model = deeper_sequential_model(INPUT_SHAPE, NUM_CLASSES)
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_9 (Rescaling)     (None, 32, 32, 3)         0
#
#  conv2d_33 (Conv2D)          (None, 32, 32, 64)        1792
#
#  max_pooling2d_33 (MaxPoolin  (None, 16, 16, 64)       0
#  g2D)
#
#  normalization_33 (Normaliza  (None, 16, 16, 64)       129
#  tion)
#
#  conv2d_34 (Conv2D)          (None, 16, 16, 128)       73856
#
#  max_pooling2d_34 (MaxPoolin  (None, 8, 8, 128)        0
#  g2D)
#
#  normalization_34 (Normaliza  (None, 8, 8, 128)        257
#  tion)
#
#  conv2d_35 (Conv2D)          (None, 8, 8, 256)         295168
#
#  max_pooling2d_35 (MaxPoolin  (None, 4, 4, 256)        0
#  g2D)
#
#  normalization_35 (Normaliza  (None, 4, 4, 256)        513
#  tion)
#
#  flatten_9 (Flatten)         (None, 4096)              0
#
#  dropout_19 (Dropout)        (None, 4096)              0
#
#  dense_28 (Dense)            (None, 256)               1048832
#
#  dropout_20 (Dropout)        (None, 256)               0
#
#  dense_29 (Dense)            (None, 128)               32896
#
#  dropout_21 (Dropout)        (None, 128)               0
#
#  dense_30 (Dense)            (None, 32)                4128
#
#  dropout_22 (Dropout)        (None, 32)                0
#
#  dense_31 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 1,457,901
# Trainable params: 1,457,002
# Non-trainable params: 899
# _________________________________________________________________

# %%
# callbacks
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint

# Early stopping
es = EarlyStopping(monitor='val_accuracy', verbose=1, patience=5, mode='max')
# learning rate scheduler
lrd = LearningRateScheduler(lambda epoch: 1 / 10**(3 + epoch // 6))
# model checkpoint
mdl_check = ModelCheckpoint(filepath=f'{MODELS_PATH}/deeper_sequential.h5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

callbacks = [es, mdl_check]

# %%
history = model.fit(train_images, y_train, 
                    epochs=30, batch_size=64,
                    validation_split=0.2, callbacks=callbacks)
# Out:
# Epoch 1/30
# 2022-06-12 14:13:34.404358: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 624/625 [============================>.] - ETA: 0s - loss: 1.8240 - accuracy: 0.3149
# 2022-06-12 14:13:51.409721: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_accuracy improved from -inf to 0.47050, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 19s 29ms/step - loss: 1.8234 - accuracy: 0.3152 - val_loss: 1.4196 - val_accuracy: 0.4705
# Epoch 2/30
# 624/625 [============================>.] - ETA: 0s - loss: 1.3136 - accuracy: 0.5301
# Epoch 2: val_accuracy improved from 0.47050 to 0.60300, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 18s 29ms/step - loss: 1.3134 - accuracy: 0.5301 - val_loss: 1.1027 - val_accuracy: 0.6030
# Epoch 3/30
# 624/625 [============================>.] - ETA: 0s - loss: 1.1041 - accuracy: 0.6102
# Epoch 3: val_accuracy improved from 0.60300 to 0.66510, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 18s 29ms/step - loss: 1.1039 - accuracy: 0.6103 - val_loss: 0.9857 - val_accuracy: 0.6651
# Epoch 4/30
# 625/625 [==============================] - ETA: 0s - loss: 0.9685 - accuracy: 0.6609
# Epoch 4: val_accuracy improved from 0.66510 to 0.67770, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 18s 30ms/step - loss: 0.9685 - accuracy: 0.6609 - val_loss: 0.9293 - val_accuracy: 0.6777
# Epoch 5/30
# 625/625 [==============================] - ETA: 0s - loss: 0.8694 - accuracy: 0.6973
# Epoch 5: val_accuracy improved from 0.67770 to 0.71840, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 19s 30ms/step - loss: 0.8694 - accuracy: 0.6973 - val_loss: 0.8334 - val_accuracy: 0.7184
# Epoch 6/30
# 624/625 [============================>.] - ETA: 0s - loss: 0.7885 - accuracy: 0.7271
# Epoch 6: val_accuracy improved from 0.71840 to 0.73020, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 19s 30ms/step - loss: 0.7884 - accuracy: 0.7272 - val_loss: 0.7962 - val_accuracy: 0.7302
# Epoch 7/30
# 625/625 [==============================] - ETA: 0s - loss: 0.7228 - accuracy: 0.7492
# Epoch 7: val_accuracy improved from 0.73020 to 0.73050, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 19s 31ms/step - loss: 0.7228 - accuracy: 0.7492 - val_loss: 0.8049 - val_accuracy: 0.7305
# Epoch 8/30
# 624/625 [============================>.] - ETA: 0s - loss: 0.6572 - accuracy: 0.7740
# Epoch 8: val_accuracy improved from 0.73050 to 0.74440, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 21s 34ms/step - loss: 0.6570 - accuracy: 0.7740 - val_loss: 0.7688 - val_accuracy: 0.7444
# Epoch 9/30
# 625/625 [==============================] - ETA: 0s - loss: 0.6085 - accuracy: 0.7907
# Epoch 9: val_accuracy did not improve from 0.74440
# 625/625 [==============================] - 19s 30ms/step - loss: 0.6085 - accuracy: 0.7907 - val_loss: 0.7635 - val_accuracy: 0.7434
# Epoch 10/30
# 624/625 [============================>.] - ETA: 0s - loss: 0.5840 - accuracy: 0.7971
# Epoch 10: val_accuracy did not improve from 0.74440
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5839 - accuracy: 0.7971 - val_loss: 0.7568 - val_accuracy: 0.7444
# Epoch 11/30
# 624/625 [============================>.] - ETA: 0s - loss: 0.5417 - accuracy: 0.8138
# Epoch 11: val_accuracy improved from 0.74440 to 0.75730, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 20s 32ms/step - loss: 0.5416 - accuracy: 0.8139 - val_loss: 0.7263 - val_accuracy: 0.7573
# Epoch 12/30
# 625/625 [==============================] - ETA: 0s - loss: 0.4927 - accuracy: 0.8290
# Epoch 12: val_accuracy did not improve from 0.75730
# 625/625 [==============================] - 21s 33ms/step - loss: 0.4927 - accuracy: 0.8290 - val_loss: 0.7437 - val_accuracy: 0.7557
# Epoch 13/30
# 624/625 [============================>.] - ETA: 0s - loss: 0.4685 - accuracy: 0.8378
# Epoch 13: val_accuracy did not improve from 0.75730
# 625/625 [==============================] - 20s 32ms/step - loss: 0.4686 - accuracy: 0.8377 - val_loss: 0.7431 - val_accuracy: 0.7566
# Epoch 14/30
# 625/625 [==============================] - ETA: 0s - loss: 0.4389 - accuracy: 0.8479
# Epoch 14: val_accuracy did not improve from 0.75730
# 625/625 [==============================] - 22s 36ms/step - loss: 0.4389 - accuracy: 0.8479 - val_loss: 0.7598 - val_accuracy: 0.7530
# Epoch 15/30
# 624/625 [============================>.] - ETA: 0s - loss: 0.4212 - accuracy: 0.8562
# Epoch 15: val_accuracy improved from 0.75730 to 0.75990, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 23s 37ms/step - loss: 0.4212 - accuracy: 0.8563 - val_loss: 0.7602 - val_accuracy: 0.7599
# Epoch 16/30
# 625/625 [==============================] - ETA: 0s - loss: 0.3968 - accuracy: 0.8640
# Epoch 16: val_accuracy improved from 0.75990 to 0.77060, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 26s 41ms/step - loss: 0.3968 - accuracy: 0.8640 - val_loss: 0.7153 - val_accuracy: 0.7706
# Epoch 17/30
# 624/625 [============================>.] - ETA: 0s - loss: 0.3719 - accuracy: 0.8712
# Epoch 17: val_accuracy improved from 0.77060 to 0.77110, saving model to /Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/CIFAR-10/models/simple_sequential.h5
# 625/625 [==============================] - 25s 39ms/step - loss: 0.3718 - accuracy: 0.8712 - val_loss: 0.7223 - val_accuracy: 0.7711
# Epoch 18/30
# 625/625 [==============================] - ETA: 0s - loss: 0.3522 - accuracy: 0.8792
# Epoch 18: val_accuracy did not improve from 0.77110
# 625/625 [==============================] - 25s 40ms/step - loss: 0.3522 - accuracy: 0.8792 - val_loss: 0.8097 - val_accuracy: 0.7545
# Epoch 19/30
# 624/625 [============================>.] - ETA: 0s - loss: 0.3448 - accuracy: 0.8818
# Epoch 19: val_accuracy did not improve from 0.77110
# 625/625 [==============================] - 25s 40ms/step - loss: 0.3450 - accuracy: 0.8817 - val_loss: 0.7549 - val_accuracy: 0.7673
# Epoch 20/30
# 625/625 [==============================] - ETA: 0s - loss: 0.3239 - accuracy: 0.8887
# Epoch 20: val_accuracy did not improve from 0.77110
# 625/625 [==============================] - 25s 40ms/step - loss: 0.3239 - accuracy: 0.8887 - val_loss: 0.7675 - val_accuracy: 0.7663
# Epoch 21/30
# 624/625 [============================>.] - ETA: 0s - loss: 0.3025 - accuracy: 0.8965
# Epoch 21: val_accuracy did not improve from 0.77110
# 625/625 [==============================] - 27s 44ms/step - loss: 0.3023 - accuracy: 0.8966 - val_loss: 0.7954 - val_accuracy: 0.7642
# Epoch 22/30
# 625/625 [==============================] - ETA: 0s - loss: 0.2925 - accuracy: 0.9006
# Epoch 22: val_accuracy did not improve from 0.77110
# 625/625 [==============================] - 25s 41ms/step - loss: 0.2925 - accuracy: 0.9006 - val_loss: 0.7946 - val_accuracy: 0.7701
# Epoch 22: early stopping

# %%
plot_model_performance(history)

# %%
model.evaluate(test_images, y_test)
# Out:
# 313/313 [==============================] - 3s 11ms/step - loss: 0.8484 - accuracy: 0.7587
# [0.8484305143356323, 0.7587000131607056]

# %% [markdown]
# ## Testing Performance

# %%
from sklearn.metrics import confusion_matrix, classification_report 

def confusion_matrix_plot(y_test, y_pred, figsize=(12, 10), labels=None):
    plt.figure(figsize=figsize)
    cm = confusion_matrix(y_test, y_pred)
    cm_plot = sns.heatmap(cm, annot=True, fmt='d', cmap="YlGnBu")
    cm_plot.set_title('Confusion Matrix')
    cm_plot.set_xlabel('Predicted Label')
    cm_plot.set_ylabel('True Label')
    if labels:
        cm_plot.set_xticklabels(labels)
        cm_plot.set_yticklabels(labels)
        
    plt.show()
    
def classification_report_plot(y_test, y_pred, figsize=(12, 10), labels=None):
    plt.figure(figsize=figsize)
    cr = classification_report(y_test, y_pred, output_dict=True)
    if labels:
        cr = classification_report(y_test, y_pred, output_dict=True, target_names=labels)
    cr_heatmap = sns.heatmap(pd.DataFrame(cr).iloc[:-1, :].T, annot=True, cmap="YlGnBu", fmt='.2f')
    cr_heatmap.set_title('Classification Report')
    cr_heatmap.set_xlabel('Metrics')
    cr_heatmap.set_ylabel('Classes')
        
    plt.show()

# %% [markdown]
# ### Simple Sequential Model

# %%
from tensorflow.keras.models import load_model
model = load_model(f'{MODELS_PATH}/simple_sequential.h5')

# %% [markdown]
# #### Performance Heatmap

# %%
#  confusion matrix and classification report
from sklearn.metrics import accuracy_score

x, y = test_images, test_labels
test_labels_pred = predict_label(x, model)
print("Accuracy:", accuracy_score(y, test_labels_pred))
confusion_matrix_plot(y, test_labels_pred, labels=CLASS_NAMES)
classification_report_plot(y, test_labels_pred, labels=CLASS_NAMES)
# Out:
# 2022-06-12 13:56:11.751298: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Accuracy: 0.7533

# %% [markdown]
# #### Data Visualization

# %%
test_labels
# Out:
# array([3, 8, 8, ..., 5, 1, 7], dtype=uint8)

# %%
rnd_pts = np.random.randint(0, test_images.shape[0], 25)
images = test_images[rnd_pts, :, :]
labels = test_labels[rnd_pts]
labels_pred  = test_labels_pred[rnd_pts]

display_image_grid(images, give_class_name(labels), give_class_name(labels_pred))

# %%
# Plotting only the incorrect images

labels_pred = predict_label(test_images, model)
incorrect_pred = test_labels != labels_pred

rnd_pts = np.random.randint(0, incorrect_pred.sum(), 16)

images = test_images[incorrect_pred, :, :][rnd_pts, :, :]
labels = test_labels[incorrect_pred][rnd_pts]
labels_pred = labels_pred[incorrect_pred][rnd_pts]

display_image_grid(images, give_class_name(labels), give_class_name(labels_pred), shape=(4, 4), figsize=(12, 12))

# %% [markdown]
# ### Deeper Sequential Model

# %%
from tensorflow.keras.models import load_model
model = load_model(f'{MODELS_PATH}/deeper_sequential.h5')

# %% [markdown]
# #### Performance Heatmap

# %%
#  confusion matrix and classification report
from sklearn.metrics import accuracy_score

x, y = test_images, test_labels
test_labels_pred = predict_label(x, model)
print("Accuracy:", accuracy_score(y, test_labels_pred))
confusion_matrix_plot(y, test_labels_pred, labels=CLASS_NAMES)
classification_report_plot(y, test_labels_pred, labels=CLASS_NAMES)
# Out:
# 2022-06-12 13:56:11.751298: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# Accuracy: 0.7533

# %% [markdown]
# #### Data Visualization

# %%
test_labels
# Out:
# array([3, 8, 8, ..., 5, 1, 7], dtype=uint8)

# %%
rnd_pts = np.random.randint(0, test_images.shape[0], 25)
images = test_images[rnd_pts, :, :]
labels = test_labels[rnd_pts]
labels_pred  = test_labels_pred[rnd_pts]

display_image_grid(images, give_class_name(labels), give_class_name(labels_pred))

# %%
# Plotting only the incorrect images

labels_pred = predict_label(test_images, model)
incorrect_pred = test_labels != labels_pred

rnd_pts = np.random.randint(0, incorrect_pred.sum(), 16)

images = test_images[incorrect_pred, :, :][rnd_pts, :, :]
labels = test_labels[incorrect_pred][rnd_pts]
labels_pred = labels_pred[incorrect_pred][rnd_pts]

display_image_grid(images, give_class_name(labels), give_class_name(labels_pred), shape=(4, 4), figsize=(12, 12))

# %% [markdown]
# ## Results

# %% [markdown]
# ### 75% is not good enough accuracy, Will apply more models untill we get good results

# %% [markdown]
# ### Simple Sequential Model with Dropout

# %%
classification_report_plot(y, test_labels_pred)
