# %% [markdown]
# # Xception Notebook
#
# Contains The Implementation of Xception Model, through Transfer Learning.

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import os
import pathlib
import sys

# %% [markdown]
# ## Contents

# %% [markdown]
# ### Directories

# %%
# go to parent directory
os.chdir("../..")
import paths

REPO_DIR = paths.get_repo_path()
ROOT_DIR = REPO_DIR / "Stanford Dogs"
DATA_BASE_PATH = paths.get_data_path() / "stanford-dogs-dataset"
DATA_PATH = DATA_BASE_PATH / "splited-data"

TRAIN_PATH = DATA_PATH / "train"
TEST_PATH = DATA_PATH / "test"

# set path to repo_dir
os.chdir(REPO_DIR)

# %% [markdown]
# ## Data

# %% [markdown]
# ### Variables

# %%
RANDOM_SEED = 42
IMAGE_WIDTH = 224
IMAGE_HEIGHT = 224

VALIDATION_SPLIT = 0.2

BATCH_SIZE = 32

CLASS_NAMES = sorted([img_cls for img_cls in  os.listdir(TRAIN_PATH) if img_cls != ".DS_Store"])
NUM_CLASSES = len(CLASS_NAMES)

# MODEL
MODEL_PATH = ROOT_DIR / "models"
LOG_PATH = ROOT_DIR / "log"

# %%
tf.random.set_seed(RANDOM_SEED)

# %% [markdown]
# ### Data Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_generator = ImageDataGenerator(
    rescale=1./255,
    
    horizontal_flip=True,
    
    rotation_range=20,
    
    height_shift_range=0.1,       # No need to shift the image
    width_shift_range=0.1,
    zoom_range=0.1,
    
    shear_range=0.1,              # Seems to be useful
    
    validation_split=VALIDATION_SPLIT,
)

val_generator = ImageDataGenerator(
    rescale=1./255,
    validation_split=VALIDATION_SPLIT,
    )

test_generator = ImageDataGenerator(
    rescale=1./255,
)

# %%
train_images = train_generator.flow_from_directory(
    TRAIN_PATH,
    target_size=(IMAGE_WIDTH, IMAGE_HEIGHT),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    
    shuffle=True,
    seed=42,
    
    subset='training',
)

val_images = val_generator.flow_from_directory(
    TRAIN_PATH,
    target_size=(IMAGE_WIDTH, IMAGE_HEIGHT),
    color_mode='rgb',
    class_mode='categorical',
    batch_size=BATCH_SIZE,
    
    shuffle=True,
    seed=42,
    
    subset='validation'
)


test_images = test_generator.flow_from_directory(
    TEST_PATH,
    target_size=(IMAGE_WIDTH, IMAGE_HEIGHT),
    color_mode='rgb',
    class_mode='categorical',
    
    batch_size=BATCH_SIZE,
    
    shuffle=False,
    seed=42,
)

NUM_TRAIN_IMAGES = len(train_images.filenames)
NUM_VAL_IMAGES = len(val_images.filenames)
NUM_TEST_IMAGES = len(test_images.filenames)
# Out:
# Found 12369 images belonging to 120 classes.
# Found 3025 images belonging to 120 classes.
# Found 5186 images belonging to 120 classes.

# %% [markdown]
# ### LOADING DATA

# %%
from sklearn.preprocessing import LabelEncoder

def give_class_name(y:np.ndarray) -> np.ndarray:
    if len(y.shape) == 2:
        y = y.argmax(axis=1)
    enc = LabelEncoder().fit(CLASS_NAMES)
    y_labeled = enc.inverse_transform(y)
    
    return y_labeled

# display images in a grid function
def display_image_grid(images, labels, pred_val=None,shape=(5, 5), figsize=(10, 10)):
    plt.figure(figsize=figsize)
    m = shape[0] * shape[1]
    
    if images.shape[0] < m:
        raise ValueError("images.shape[0] must equal shape[0] * shape[1]")
    
    if labels.shape[0] != images.shape[0]:
        raise ValueError("labels.shape[0] must equal images.shape[0]")
    
    if pred_val is not None and pred_val.shape[0] != images.shape[0]:
        raise ValueError("pred_val.shape[0] must equal images.shape[0]")
    
    for i in range(m):
        plt.subplot(shape[0], shape[1], i+1)
        plt.imshow(images[i], cmap="gray", interpolation="none")
        title = labels[i]
        if pred_val is not None:
            title = f"{pred_val[i]}"
            if pred_val[i] != labels[i]:
                title += f"\n*({labels[i]})*"
        plt.title(title)
        plt.axis("off")
        # increase vertical space between subplots
        plt.subplots_adjust(wspace=0.1, hspace=0.4)
    plt.show()

# %%
CLASS_NAMES = list(train_images.class_indices)

CLASS_NAMES[:10]
# Out:
# ['Affenpinscher',
#  'Afghan Hound',
#  'African Hunting Dog',
#  'Airedale',
#  'American Staffordshire Terrier',
#  'Appenzeller',
#  'Australian Terrier',
#  'Basenji',
#  'Basset',
#  'Beagle']

# %%
num_rows = 8
num_cols = 4

plt.figure(figsize=(20, 18))

images, labels = train_images.next()
for i in range(num_cols * num_rows):
    plt.subplot(num_cols, num_rows, i + 1)
    plt.imshow(images[i])
    plt.title(CLASS_NAMES[labels[i].argmax()])
    plt.axis('off')

plt.show()

# %% [markdown]
# ## Model

# %%
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, Rescaling, Input, Add, Activation, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, f1_score, precision_score, recall_score

# %% [markdown]
# ### Valribles

# %%
INPUT_SHAPE = train_images.next()[0][0].shape
TRAIN_MODELS = True
# TRAIN_MODELS = False

# %% [markdown]
# ### Useful functions ###

# %%
def predict_label(images, model):
    predictions = model.predict(images)
    return predictions.argmax(axis=1)


# ploting the model training history
def plot_model_performance(history, figsize=(10, 10)):
    preformance = {key: val for key, val in history.history.items() if "loss" not in key}
    losses = {key: val for key, val in history.history.items() if "loss" in key}
    
    plt.figure(figsize=figsize)
    plt.title('Model Performance')
    for key, val in preformance.items():
        plt.plot(val, label=key)
    plt.legend(preformance.keys())
    plt.xlabel('Epoch')
    
    plt.figure(figsize=figsize)
    plt.title('Model Losses')
    for key, val in losses.items():
        plt.plot(val, label=key)
    plt.legend(losses.keys())
    plt.xlabel('Epoch')
    
    plt.show()


def get_model_performance(y_true, y_pred):
    if len(y_true.shape) == 2:
        y_true = y_true.argmax(axis=1)
    if len(y_pred.shape) == 2:
        y_pred = y_pred.argmax(axis=1)

    accuracy = accuracy_score(y_true, y_pred)
    f1_scr = f1_score(y_true, y_pred, average='weighted')
    precision_scr = precision_score(y_true, y_pred, average='weighted')
    recall_scr = recall_score(y_true, y_pred, average='weighted')
    
    performance = {
        "Accuracy": accuracy,
        "F1 Score": f1_scr,
        "Precision": precision_scr,
        "Recall": recall_scr
    }
    
    return performance

# %% [markdown]
# ### MODELS

# %% [markdown]
# #### MODEL ARCHITECTURE

# %%
from tensorflow.keras.models import Sequential

model_name = "Xception"
weight_decay = 10e-5
LEARNING_RATE = 2e-4
# weight_decay = 0

def final_model(tl_model, num_classes: int):
    model = Sequential(name=model_name)
    
    tl_model.trainable = False
    model.add(tl_model)
    model.add(GlobalAveragePooling2D())
    
    model.add(Dropout(0.3))
    
    model.add(Dense(512, kernel_regularizer=l2(weight_decay)))
    model.add(BatchNormalization())
    model.add(Activation("relu"))
    
    model.add(Dropout(0.4))
    
    model.add(Dense(num_classes, activation='softmax'))
    
    return model

# %%
from tensorflow.keras.applications.xception import Xception

tl_model = Xception(include_top=False, weights='imagenet', input_shape=INPUT_SHAPE)

print("Total Params:", tl_model.count_params())
# Out:
# 2022-07-11 13:25:01.486705: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 13:25:01.506156: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 13:25:01.506288: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 13:25:01.506684: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-07-11 13:25:01.506981: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 13:25:01.507070: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 13:25:01.507146: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 13:25:01.822039: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 13:25:01.822180: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 13:25:01.822269: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-07-11 13:25:01.822340: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5958 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:01:00.0, compute capability: 8.6
# Total Params: 20861480

# %%
model = final_model(tl_model, num_classes=NUM_CLASSES)

model.compile(
        optimizer=Adam(learning_rate=LEARNING_RATE), 
        loss='categorical_crossentropy', 
        metrics=[
            'accuracy',
            'top_k_categorical_accuracy',
            ]
        )
model.summary()
# Out:
# Model: "Xception"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 7, 7, 2048)        20861480
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  batch_normalization_4 (Batc  (None, 512)              2048
#  hNormalization)
#
#  activation (Activation)     (None, 512)               0
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 120)               61560
#
# =================================================================
# Total params: 21,974,176
# Trainable params: 1,111,672
# Non-trainable params: 20,862,504
# _________________________________________________________________

# %% [markdown]
# #### Model Training

# %%
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint, CSVLogger

monitor_metric = 'val_accuracy'

# Early stopping
es = EarlyStopping(
        monitor=monitor_metric,
        patience=5,
        mode = "auto",
        verbose=1,
)

# Learning rate scheduler
def step_decay(epoch):
    initial_lr = LEARNING_RATE
    k = 0.1
    lr = initial_lr * np.exp(-k*epoch)
    return lr

lrd = LearningRateScheduler(step_decay)

# Model Checkpoint
mdl_check = ModelCheckpoint(
        MODEL_PATH / f"{model_name}.h5",
        monitor=monitor_metric,
        save_best_only=True,
        mode='auto',
        verbose=1,
)
        
# CSV Logger
csv_logger = CSVLogger(
        LOG_PATH / f"{model_name}.csv",
        append=False,
)


callbacks = [
        es, 
        lrd,
        mdl_check, 
        # csv_logger,
    ]

# %%
from tensorflow.keras.models import load_model

train_model = not (os.path.exists(MODEL_PATH / f"{model_name}.h5")) or TRAIN_MODELS

if train_model:
    history = model.fit(train_images, 
                        validation_data=val_images,
                        epochs=50, 
                        callbacks=callbacks,
)
else:
    model_path = MODEL_PATH / f"{model_name}.h5"
    model = load_model(model_path)
    print(f"{model_name} model loaded from {model_path}")
# Out:
# Epoch 1/50
# 2022-07-11 13:25:04.527071: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8201
# 2022-07-11 13:25:05.104130: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-07-11 13:25:05.104658: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-07-11 13:25:05.104672: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2022-07-11 13:25:05.105186: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-07-11 13:25:05.105227: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
#   2/387 [..............................] - ETA: 20s - loss: 5.6073 - accuracy: 0.0000e+00 - top_k_categorical_accuracy: 0.0625
# 2022-07-11 13:25:05.866253: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 387/387 [==============================] - ETA: 0s - loss: 2.4527 - accuracy: 0.4891 - top_k_categorical_accuracy: 0.7241
# Epoch 1: val_accuracy improved from -inf to 0.77289, saving model to /home/vineet/.personal/code/Hello-CNN/Stanford Dogs/models/Xception.h5
# 387/387 [==============================] - 71s 176ms/step - loss: 2.4527 - accuracy: 0.4891 - top_k_categorical_accuracy: 0.7241 - val_loss: 0.9806 - val_accuracy: 0.7729 - val_top_k_categorical_accuracy: 0.9570 - lr: 2.0000e-04
# Epoch 2/50
# 387/387 [==============================] - ETA: 0s - loss: 1.2498 - accuracy: 0.6990 - top_k_categorical_accuracy: 0.9204
# Epoch 2: val_accuracy improved from 0.77289 to 0.79273, saving model to /home/vineet/.personal/code/Hello-CNN/Stanford Dogs/models/Xception.h5
# 387/387 [==============================] - 68s 177ms/step - loss: 1.2498 - accuracy: 0.6990 - top_k_categorical_accuracy: 0.9204 - val_loss: 0.8250 - val_accuracy: 0.7927 - val_top_k_categorical_accuracy: 0.9626 - lr: 1.8097e-04
# Epoch 3/50
# 387/387 [==============================] - ETA: 0s - loss: 1.0896 - accuracy: 0.7262 - top_k_categorical_accuracy: 0.9369
# Epoch 3: val_accuracy improved from 0.79273 to 0.80231, saving model to /home/vineet/.personal/code/Hello-CNN/Stanford Dogs/models/Xception.h5
# 387/387 [==============================] - 68s 175ms/step - loss: 1.0896 - accuracy: 0.7262 - top_k_categorical_accuracy: 0.9369 - val_loss: 0.7813 - val_accuracy: 0.8023 - val_top_k_categorical_accuracy: 0.9643 - lr: 1.6375e-04
# Epoch 4/50
# 387/387 [==============================] - ETA: 0s - loss: 0.9966 - accuracy: 0.7442 - top_k_categorical_accuracy: 0.9462
# Epoch 4: val_accuracy did not improve from 0.80231
# 387/387 [==============================] - 68s 175ms/step - loss: 0.9966 - accuracy: 0.7442 - top_k_categorical_accuracy: 0.9462 - val_loss: 0.7672 - val_accuracy: 0.7993 - val_top_k_categorical_accuracy: 0.9663 - lr: 1.4816e-04
# Epoch 5/50
# 387/387 [==============================] - ETA: 0s - loss: 0.9439 - accuracy: 0.7555 - top_k_categorical_accuracy: 0.9490
# Epoch 5: val_accuracy improved from 0.80231 to 0.80264, saving model to /home/vineet/.personal/code/Hello-CNN/Stanford Dogs/models/Xception.h5
# 387/387 [==============================] - 68s 176ms/step - loss: 0.9439 - accuracy: 0.7555 - top_k_categorical_accuracy: 0.9490 - val_loss: 0.7563 - val_accuracy: 0.8026 - val_top_k_categorical_accuracy: 0.9669 - lr: 1.3406e-04
# Epoch 6/50
# 387/387 [==============================] - ETA: 0s - loss: 0.9123 - accuracy: 0.7633 - top_k_categorical_accuracy: 0.9517
# Epoch 6: val_accuracy improved from 0.80264 to 0.80694, saving model to /home/vineet/.personal/code/Hello-CNN/Stanford Dogs/models/Xception.h5
# 387/387 [==============================] - 68s 175ms/step - loss: 0.9123 - accuracy: 0.7633 - top_k_categorical_accuracy: 0.9517 - val_loss: 0.7510 - val_accuracy: 0.8069 - val_top_k_categorical_accuracy: 0.9663 - lr: 1.2131e-04
# Epoch 7/50
# 387/387 [==============================] - ETA: 0s - loss: 0.8793 - accuracy: 0.7710 - top_k_categorical_accuracy: 0.9575
# Epoch 7: val_accuracy did not improve from 0.80694
# 387/387 [==============================] - 68s 175ms/step - loss: 0.8793 - accuracy: 0.7710 - top_k_categorical_accuracy: 0.9575 - val_loss: 0.7448 - val_accuracy: 0.8050 - val_top_k_categorical_accuracy: 0.9669 - lr: 1.0976e-04
# Epoch 8/50
# 387/387 [==============================] - ETA: 0s - loss: 0.8499 - accuracy: 0.7738 - top_k_categorical_accuracy: 0.9594
# Epoch 8: val_accuracy did not improve from 0.80694
# 387/387 [==============================] - 68s 176ms/step - loss: 0.8499 - accuracy: 0.7738 - top_k_categorical_accuracy: 0.9594 - val_loss: 0.7409 - val_accuracy: 0.8063 - val_top_k_categorical_accuracy: 0.9666 - lr: 9.9317e-05
# Epoch 9/50
# 387/387 [==============================] - ETA: 0s - loss: 0.8265 - accuracy: 0.7847 - top_k_categorical_accuracy: 0.9632
# Epoch 9: val_accuracy improved from 0.80694 to 0.80860, saving model to /home/vineet/.personal/code/Hello-CNN/Stanford Dogs/models/Xception.h5
# 387/387 [==============================] - 68s 175ms/step - loss: 0.8265 - accuracy: 0.7847 - top_k_categorical_accuracy: 0.9632 - val_loss: 0.7411 - val_accuracy: 0.8086 - val_top_k_categorical_accuracy: 0.9660 - lr: 8.9866e-05
# Epoch 10/50
# 387/387 [==============================] - ETA: 0s - loss: 0.8038 - accuracy: 0.7874 - top_k_categorical_accuracy: 0.9653
# Epoch 10: val_accuracy did not improve from 0.80860
# 387/387 [==============================] - 68s 176ms/step - loss: 0.8038 - accuracy: 0.7874 - top_k_categorical_accuracy: 0.9653 - val_loss: 0.7411 - val_accuracy: 0.8076 - val_top_k_categorical_accuracy: 0.9650 - lr: 8.1314e-05
# Epoch 11/50
# 387/387 [==============================] - ETA: 0s - loss: 0.7978 - accuracy: 0.7846 - top_k_categorical_accuracy: 0.9655
# Epoch 11: val_accuracy improved from 0.80860 to 0.81091, saving model to /home/vineet/.personal/code/Hello-CNN/Stanford Dogs/models/Xception.h5
# 387/387 [==============================] - 68s 177ms/step - loss: 0.7978 - accuracy: 0.7846 - top_k_categorical_accuracy: 0.9655 - val_loss: 0.7402 - val_accuracy: 0.8109 - val_top_k_categorical_accuracy: 0.9653 - lr: 7.3576e-05
# Epoch 12/50
# 387/387 [==============================] - ETA: 0s - loss: 0.7832 - accuracy: 0.7909 - top_k_categorical_accuracy: 0.9673
# Epoch 12: val_accuracy did not improve from 0.81091
# 387/387 [==============================] - 68s 176ms/step - loss: 0.7832 - accuracy: 0.7909 - top_k_categorical_accuracy: 0.9673 - val_loss: 0.7385 - val_accuracy: 0.8089 - val_top_k_categorical_accuracy: 0.9643 - lr: 6.6574e-05
# Epoch 13/50
# 387/387 [==============================] - ETA: 0s - loss: 0.7704 - accuracy: 0.7932 - top_k_categorical_accuracy: 0.9681
# Epoch 13: val_accuracy did not improve from 0.81091
# 387/387 [==============================] - 68s 175ms/step - loss: 0.7704 - accuracy: 0.7932 - top_k_categorical_accuracy: 0.9681 - val_loss: 0.7369 - val_accuracy: 0.8102 - val_top_k_categorical_accuracy: 0.9640 - lr: 6.0239e-05
# Epoch 14/50
# 387/387 [==============================] - ETA: 0s - loss: 0.7510 - accuracy: 0.8003 - top_k_categorical_accuracy: 0.9707
# Epoch 14: val_accuracy did not improve from 0.81091
# 387/387 [==============================] - 68s 176ms/step - loss: 0.7510 - accuracy: 0.8003 - top_k_categorical_accuracy: 0.9707 - val_loss: 0.7354 - val_accuracy: 0.8066 - val_top_k_categorical_accuracy: 0.9643 - lr: 5.4506e-05
# Epoch 15/50
# 387/387 [==============================] - ETA: 0s - loss: 0.7443 - accuracy: 0.8047 - top_k_categorical_accuracy: 0.9692
# Epoch 15: val_accuracy did not improve from 0.81091
# 387/387 [==============================] - 69s 178ms/step - loss: 0.7443 - accuracy: 0.8047 - top_k_categorical_accuracy: 0.9692 - val_loss: 0.7360 - val_accuracy: 0.8106 - val_top_k_categorical_accuracy: 0.9653 - lr: 4.9319e-05
# Epoch 16/50
# 387/387 [==============================] - ETA: 0s - loss: 0.7348 - accuracy: 0.8060 - top_k_categorical_accuracy: 0.9711
# Epoch 16: val_accuracy did not improve from 0.81091
# 387/387 [==============================] - 68s 175ms/step - loss: 0.7348 - accuracy: 0.8060 - top_k_categorical_accuracy: 0.9711 - val_loss: 0.7358 - val_accuracy: 0.8083 - val_top_k_categorical_accuracy: 0.9650 - lr: 4.4626e-05
# Epoch 16: early stopping

# %%
if train_model:
    plot_model_performance(history)

# %%
if train_model:
    model.evaluate(test_images)
# Out:
# 163/163 [==============================] - 9s 52ms/step - loss: 0.7345 - accuracy: 0.8083 - top_k_categorical_accuracy: 0.9649

# %%
test_images.batch_size = 7

test_labels = test_images.labels
test_labels_pred_ohe = model.predict(test_images)
test_labels_pred = test_labels_pred_ohe.argmax(axis=1)

# %%
plt_size = (20, 18)

test_images.shuffle = True

num_rows = 6
num_cols = 4

test_images.batch_size = num_rows * num_cols

images, labels = test_images.next()
labels_pred = predict_label(images, model)

display_image_grid(
                images, 
                give_class_name(labels), give_class_name(labels_pred),
                shape=(num_rows, num_cols),
                figsize=plt_size,
                )

# %%
#  confusion matrix and classification report

performance = get_model_performance(test_labels, test_labels_pred)
print(classification_report(test_labels, test_labels_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.76      0.82        38
#            1       0.90      0.93      0.92        60
#            2       0.96      1.00      0.98        43
#            3       0.81      0.76      0.79        51
#            4       0.62      0.61      0.62        41
#            5       0.80      0.63      0.71        38
#            6       0.79      0.67      0.73        49
#            7       0.79      0.91      0.84        53
#            8       0.91      0.91      0.91        44
#            9       0.71      0.73      0.72        49
#           10       1.00      0.93      0.97        46
#           11       0.89      0.98      0.93        55
#           12       0.75      0.75      0.75        40
#           13       0.92      0.96      0.94        47
#           14       0.82      0.85      0.83        47
#           15       0.88      0.86      0.87        43
#           16       0.69      0.87      0.77        38
#           17       0.82      0.93      0.87        43
#           18       0.89      0.89      0.89        38
#           19       0.90      0.93      0.91        46
#           20       0.85      0.87      0.86        38
#           21       0.82      0.82      0.82        38
#           22       0.97      0.79      0.87        39
#           23       0.84      0.82      0.83        38
#           24       0.80      0.87      0.84        38
#           25       0.97      0.90      0.93        39
#           26       0.88      0.86      0.87        50
#           27       0.81      0.64      0.71        39
#           28       0.71      0.83      0.77        42
#           29       0.81      0.55      0.66        38
#           30       0.88      0.90      0.89        49
#           31       0.87      0.87      0.87        38
#           32       0.78      0.78      0.78        40
#           33       0.62      0.38      0.48        39
#           34       0.91      0.84      0.88        38
#           35       0.89      0.89      0.89        45
#           36       0.92      0.95      0.94        38
#           37       0.84      0.82      0.83        39
#           38       0.74      0.74      0.74        38
#           39       0.75      0.60      0.67        40
#           40       0.89      0.76      0.82        41
#           41       0.82      0.93      0.87        40
#           42       0.74      0.78      0.76        51
#           43       0.35      0.29      0.32        38
#           44       0.78      0.82      0.79        38
#           45       0.88      0.90      0.89        40
#           46       0.82      0.74      0.78        38
#           47       0.79      0.89      0.84        38
#           48       0.79      0.85      0.82        40
#           49       0.73      0.87      0.80        38
#           50       0.94      0.82      0.88        39
#           51       0.88      0.77      0.82        39
#           52       0.67      0.81      0.73        54
#           53       0.78      0.74      0.76        42
#           54       0.87      0.87      0.87        38
#           55       0.80      0.87      0.84        47
#           56       0.85      0.85      0.85        39
#           57       0.92      0.77      0.84        43
#           58       0.90      0.92      0.91        38
#           59       0.73      0.80      0.77        55
#           60       0.62      0.67      0.65        46
#           61       0.89      0.89      0.89        47
#           62       0.98      1.00      0.99        40
#           63       0.72      0.74      0.73        39
#           64       0.93      0.89      0.91        45
#           65       1.00      0.92      0.96        39
#           66       0.75      0.63      0.69        38
#           67       0.82      0.74      0.78        43
#           68       0.69      0.72      0.71        50
#           69       0.96      0.96      0.96        53
#           70       0.69      0.66      0.67        47
#           71       0.68      0.87      0.76        45
#           72       0.78      0.92      0.84        38
#           73       0.82      0.87      0.85        63
#           74       0.86      0.95      0.90        39
#           75       0.82      0.91      0.87        46
#           76       0.72      0.54      0.62        39
#           77       0.71      0.77      0.74        39
#           78       0.78      0.82      0.80        49
#           79       0.86      0.86      0.86        43
#           80       0.90      0.94      0.92        49
#           81       0.77      0.79      0.78        47
#           82       0.85      0.91      0.88        43
#           83       0.80      0.74      0.77        38
#           84       0.94      0.94      0.94        49
#           85       0.82      0.82      0.82        38
#           86       0.75      0.85      0.80        46
#           87       0.91      0.76      0.83        55
#           88       0.90      0.88      0.89        50
#           89       0.71      0.65      0.68        37
#           90       0.69      0.67      0.68        43
#           91       0.92      0.92      0.92        38
#           92       0.95      0.95      0.95        43
#           93       0.81      0.86      0.83        50
#           94       0.83      0.89      0.86        55
#           95       0.78      0.79      0.78        39
#           96       0.89      0.85      0.87        40
#           97       0.84      0.81      0.82        58
#           98       0.96      0.84      0.90        51
#           99       0.75      0.82      0.79        40
#          100       0.73      0.74      0.73        54
#          101       0.48      0.44      0.46        48
#          102       0.68      0.74      0.71        46
#          103       0.68      0.72      0.70        39
#          104       0.60      0.67      0.63        39
#          105       0.80      0.80      0.80        40
#          106       0.63      0.62      0.62        39
#          107       0.97      0.89      0.93        38
#          108       0.94      0.76      0.84        38
#          109       0.83      0.83      0.83        52
#          110       0.62      0.63      0.62        38
#          111       0.89      0.72      0.79        43
#          112       0.81      0.77      0.79        39
#          113       0.60      0.72      0.65        39
#          114       0.88      0.95      0.92        40
#          115       0.83      0.79      0.81        38
#          116       0.79      0.95      0.86        43
#          117       0.67      0.66      0.67        47
#          118       0.91      0.78      0.84        40
#          119       0.65      0.76      0.70        41
#
#     accuracy                           0.81      5186
#    macro avg       0.81      0.80      0.80      5186
# weighted avg       0.81      0.81      0.81      5186

# %%
# top 5 accuracy and classification report
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.metrics import top_k_categorical_accuracy

test_labels_ohe = tf.keras.utils.to_categorical (test_labels)
top_5_accuracy = top_k_categorical_accuracy(test_labels_ohe, test_labels_pred_ohe, k=5)

top_5_accuracy = top_5_accuracy.numpy().sum() / len(test_labels)

print(f"Top 1 Accuracy: {100* performance['Accuracy']:.2f}%")
print(f"Top 5 Accuracy: {top_5_accuracy:.2%}")
# Out:
# Top 1 Accuracy: 80.81%
# Top 5 Accuracy: 96.51%
