# %%
import torch
import torchvision
from torchvision import models
from torchvision import transforms

import torch.nn as nn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

import os
import time
import pathlib
import sys

from network import Network
import config

path_flag = False

# %%
if not path_flag:
    repo_path = pathlib.Path(os.getcwd())
    path_flag = True
base_dir = repo_path / "Neural Style Transfer/"
os.chdir(base_dir)
os.getcwd()
# Out:
# '/Users/vineetmahajan/Code/AI/Projects/Hello/Hello-CNN/Neural Style Transfer'

# %%
style_images_path = [
    "./style images/emotional-joshua-miels.jpg",
    "./style images/van-gogh.jpg"
]

# %%
from loss import NST_Loss
from torch.optim import Adam, lr_scheduler

device = torch.device("mps")

tensor_loader = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(
        (0.485, 0.456, 0.406),
        (0.229, 0.224, 0.225)
    ),
])
tensor_unloader = transforms.Compose([
    transforms.Normalize(
        (-2.12, -2.04, -1.80),
        (4.37, 4.46, 4.44)
    ),
    transforms.ToPILImage()
])

def load_image(image_path: str, ):
    """Load an image and convert it to a torch tensor."""
    image = Image.open(image_path)

    img_shape = image.size
    scale_factor = 720 / max(img_shape)
    new_img_shape = np.array(img_shape) * scale_factor
    image = image.resize(new_img_shape.astype(int), Image.Resampling.LANCZOS)

    image = tensor_loader(image).unsqueeze(0)
    return image.to(device)

style_images = [
    load_image(path_)
    for path_
    in style_images_path
]
content_image = load_image("./content images/The-Guardian.jpg")
generated_image = content_image.clone().requires_grad_(True)

learning_rate = 0.01

NST_Network = Network(style_images, content_image)
loss_fxn = NST_Loss(NST_Network.style_features, NST_Network.content_features)
optimizer = Adam([generated_image], lr=learning_rate)
scheduler = lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.01)

loss_data = {}

# for epoch in range(100):
#     generated_features = NST_Network(generated_image)
    
#     loss, misc_loss_data = loss_fxn(generated_features)
#     loss_data[epoch] = misc_loss_data
    
#     optimizer.zero_grad()
#     loss.backward()
#     optimizer.step()
# tensor_unloader(generated_image.squeeze(0))
epoch = 0
# Out:
# /Users/vineetmahajan/.pyenv/versions/miniconda3-4.12/envs/torch_gpu/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /Users/vineetmahajan/.pyenv/versions/miniconda3-4.12/envs/torch_gpu/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
for epoch in range(epoch, epoch+10):
    generated_features = NST_Network(generated_image)
    
    loss, misc_loss_data = loss_fxn(generated_features)
    loss_data[epoch] = misc_loss_data
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
cur_loss_data = loss_data[epoch]    
print(f"Epoch: {epoch+1}, Loss: {cur_loss_data['total_loss']:.2f}, Style Loss: {cur_loss_data['style_loss']:.2f}, Content Loss: {cur_loss_data['content_loss']:.2f}")
tensor_unloader(generated_image.squeeze(0))
# Out:
# Epoch: 10, Loss: 1529.41, Style Loss: 3058.64, Content Loss: 4.47
# <PIL.Image.Image image mode=RGB size=225x400>

# %%
for epoch in range(epoch, epoch+91):
    generated_features = NST_Network(generated_image)
    
    loss, misc_loss_data = loss_fxn(generated_features)
    loss_data[epoch] = misc_loss_data
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
cur_loss_data = loss_data[epoch]    
print(f"Epoch: {epoch+1}, Loss: {cur_loss_data['total_loss']:.2f}, Style Loss: {cur_loss_data['style_loss']:.2f}, Content Loss: {cur_loss_data['content_loss']:.2f}")
tensor_unloader(generated_image.squeeze(0))
# Out:
# Epoch: 100, Loss: 613.10, Style Loss: 1225.80, Content Loss: 10.19
# <PIL.Image.Image image mode=RGB size=225x400>

# %%
for epoch in range(epoch+1, epoch+101):
    generated_features = NST_Network(generated_image)
    
    loss, misc_loss_data = loss_fxn(generated_features)
    loss_data[epoch] = misc_loss_data
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
cur_loss_data = loss_data[epoch]    
print(f"Epoch: {epoch+1}, Loss: {cur_loss_data['total_loss']:.2f}, Style Loss: {cur_loss_data['style_loss']:.2f}, Content Loss: {cur_loss_data['content_loss']:.2f}")
tensor_unloader(generated_image.squeeze(0))
# Out:
# Epoch: 200, Loss: 524.22, Style Loss: 1048.00, Content Loss: 11.14
# <PIL.Image.Image image mode=RGB size=225x400>

# %%
for epoch in range(epoch+1, epoch+101):
    generated_features = NST_Network(generated_image)
    
    loss, misc_loss_data = loss_fxn(generated_features)
    loss_data[epoch] = misc_loss_data
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
cur_loss_data = loss_data[epoch]    
print(f"Epoch: {epoch+1}, Loss: {cur_loss_data['total_loss']:.2f}, Style Loss: {cur_loss_data['style_loss']:.2f}, Content Loss: {cur_loss_data['content_loss']:.2f}")
tensor_unloader(generated_image.squeeze(0))
# Out:
# Epoch: 300, Loss: 502.10, Style Loss: 1003.74, Content Loss: 11.67
# <PIL.Image.Image image mode=RGB size=225x400>

# %%
for epoch in range(epoch+1, epoch+101):
    generated_features = NST_Network(generated_image)
    
    loss, misc_loss_data = loss_fxn(generated_features)
    loss_data[epoch] = misc_loss_data
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
cur_loss_data = loss_data[epoch]    
print(f"Epoch: {epoch+1}, Loss: {cur_loss_data['total_loss']:.2f}, Style Loss: {cur_loss_data['style_loss']:.2f}, Content Loss: {cur_loss_data['content_loss']:.2f}")
tensor_unloader(generated_image.squeeze(0))
# Out:
# Epoch: 400, Loss: 498.12, Style Loss: 995.76, Content Loss: 12.03
# <PIL.Image.Image image mode=RGB size=225x400>

# %%
for epoch in range(epoch+1, epoch+101):
    generated_features = NST_Network(generated_image)
    
    loss, misc_loss_data = loss_fxn(generated_features)
    loss_data[epoch] = misc_loss_data
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
cur_loss_data = loss_data[epoch]    
print(f"Epoch: {epoch+1}, Loss: {cur_loss_data['total_loss']:.2f}, Style Loss: {cur_loss_data['style_loss']:.2f}, Content Loss: {cur_loss_data['content_loss']:.2f}")
tensor_unloader(generated_image.squeeze(0))

# %%
for epoch in range(epoch+1, epoch+101):
    generated_features = NST_Network(generated_image)
    
    loss, misc_loss_data = loss_fxn(generated_features)
    loss_data[epoch] = misc_loss_data
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
cur_loss_data = loss_data[epoch]    
print(f"Epoch: {epoch+1}, Loss: {cur_loss_data['total_loss']:.2f}, Style Loss: {cur_loss_data['style_loss']:.2f}, Content Loss: {cur_loss_data['content_loss']:.2f}")
tensor_unloader(generated_image.squeeze(0))
# Out:
# Epoch: 594, Loss: 2.32, Style Loss: 7.47, Content Loss: 41.55
# <PIL.Image.Image image mode=RGB size=225x400>

# %%
for epoch in range(epoch+1, epoch+101):
    generated_features = NST_Network(generated_image)
    
    loss, misc_loss_data = loss_fxn(generated_features)
    loss_data[epoch] = misc_loss_data
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
cur_loss_data = loss_data[epoch]    
print(f"Epoch: {epoch+1}, Loss: {cur_loss_data['total_loss']:.2f}, Style Loss: {cur_loss_data['style_loss']:.2f}, Content Loss: {cur_loss_data['content_loss']:.2f}")
tensor_unloader(generated_image.squeeze(0))
# Out:
# Epoch: 693, Loss: 2.10, Style Loss: 6.34, Content Loss: 41.64
# <PIL.Image.Image image mode=RGB size=225x400>

# %%
for epoch in range(epoch+1, epoch+101):
    generated_features = NST_Network(generated_image)
    
    loss, misc_loss_data = loss_fxn(generated_features)
    loss_data[epoch] = misc_loss_data
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
cur_loss_data = loss_data[epoch]    
print(f"Epoch: {epoch+1}, Loss: {cur_loss_data['total_loss']:.2f}, Style Loss: {cur_loss_data['style_loss']:.2f}, Content Loss: {cur_loss_data['content_loss']:.2f}")
tensor_unloader(generated_image.squeeze(0))
# Out:
# Epoch: 793, Loss: 1.94, Style Loss: 5.54, Content Loss: 41.69
# <PIL.Image.Image image mode=RGB size=225x400>

# %%
for epoch in range(epoch+1, epoch+101):
    generated_features = NST_Network(generated_image)
    
    loss, misc_loss_data = loss_fxn(generated_features)
    loss_data[epoch] = misc_loss_data
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
cur_loss_data = loss_data[epoch]    
print(f"Epoch: {epoch+1}, Loss: {cur_loss_data['total_loss']:.2f}, Style Loss: {cur_loss_data['style_loss']:.2f}, Content Loss: {cur_loss_data['content_loss']:.2f}")
tensor_unloader(generated_image.squeeze(0))
# Out:
# Epoch: 893, Loss: 1.82, Style Loss: 4.93, Content Loss: 41.70
# <PIL.Image.Image image mode=RGB size=225x400>

# %%
for epoch in range(epoch+1, epoch+101):
    generated_features = NST_Network(generated_image)
    
    loss, misc_loss_data = loss_fxn(generated_features)
    loss_data[epoch] = misc_loss_data
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
cur_loss_data = loss_data[epoch]    
print(f"Epoch: {epoch+1}, Loss: {cur_loss_data['total_loss']:.2f}, Style Loss: {cur_loss_data['style_loss']:.2f}, Content Loss: {cur_loss_data['content_loss']:.2f}")
tensor_unloader(generated_image.squeeze(0))
# Out:
# Epoch: 993, Loss: 1.72, Style Loss: 4.46, Content Loss: 41.67
# <PIL.Image.Image image mode=RGB size=225x400>

# %%
for epoch in range(epoch+1, epoch+101):
    generated_features = NST_Network(generated_image)
    
    loss, misc_loss_data = loss_fxn(generated_features)
    loss_data[epoch] = misc_loss_data
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
cur_loss_data = loss_data[epoch]    
print(f"Epoch: {epoch+1}, Loss: {cur_loss_data['total_loss']:.2f}, Style Loss: {cur_loss_data['style_loss']:.2f}, Content Loss: {cur_loss_data['content_loss']:.2f}")
tensor_unloader(generated_image.squeeze(0))
# Out:
# Epoch: 1093, Loss: 1.65, Style Loss: 4.07, Content Loss: 41.63
# <PIL.Image.Image image mode=RGB size=225x400>

# %%
for epoch in range(epoch+1, epoch+101):
    generated_features = NST_Network(generated_image)
    
    loss, misc_loss_data = loss_fxn(generated_features)
    loss_data[epoch] = misc_loss_data
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
cur_loss_data = loss_data[epoch]    
print(f"Epoch: {epoch+1}, Loss: {cur_loss_data['total_loss']:.2f}, Style Loss: {cur_loss_data['style_loss']:.2f}, Content Loss: {cur_loss_data['content_loss']:.2f}")
tensor_unloader(generated_image.squeeze(0))

# %%
for epoch in range(epoch+1, epoch+101):
    generated_features = NST_Network(generated_image)
    
    loss, misc_loss_data = loss_fxn(generated_features)
    loss_data[epoch] = misc_loss_data
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
cur_loss_data = loss_data[epoch]    
print(f"Epoch: {epoch+1}, Loss: {cur_loss_data['total_loss']:.2f}, Style Loss: {cur_loss_data['style_loss']:.2f}, Content Loss: {cur_loss_data['content_loss']:.2f}")
tensor_unloader(generated_image.squeeze(0))

# %%
for epoch in range(epoch+1, epoch+101):
    generated_features = NST_Network(generated_image)
    
    loss, misc_loss_data = loss_fxn(generated_features)
    loss_data[epoch] = misc_loss_data
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
cur_loss_data = loss_data[epoch]    
print(f"Epoch: {epoch+1}, Loss: {cur_loss_data['total_loss']:.2f}, Style Loss: {cur_loss_data['style_loss']:.2f}, Content Loss: {cur_loss_data['content_loss']:.2f}")
tensor_unloader(generated_image.squeeze(0))

# %%
for epoch in range(epoch+1, epoch+101):
    generated_features = NST_Network(generated_image)
    
    loss, misc_loss_data = loss_fxn(generated_features)
    loss_data[epoch] = misc_loss_data
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
cur_loss_data = loss_data[epoch]    
print(f"Epoch: {epoch+1}, Loss: {cur_loss_data['total_loss']:.2f}, Style Loss: {cur_loss_data['style_loss']:.2f}, Content Loss: {cur_loss_data['content_loss']:.2f}")
tensor_unloader(generated_image.squeeze(0))

# %%
for epoch in range(epoch+1, epoch+101):
    generated_features = NST_Network(generated_image)
    
    loss, misc_loss_data = loss_fxn(generated_features)
    loss_data[epoch] = misc_loss_data
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
cur_loss_data = loss_data[epoch]    
print(f"Epoch: {epoch+1}, Loss: {cur_loss_data['total_loss']:.2f}, Style Loss: {cur_loss_data['style_loss']:.2f}, Content Loss: {cur_loss_data['content_loss']:.2f}")
tensor_unloader(generated_image.squeeze(0))

# %%
for epoch in range(epoch+1, epoch+101):
    generated_features = NST_Network(generated_image)
    
    loss, misc_loss_data = loss_fxn(generated_features)
    loss_data[epoch] = misc_loss_data
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
cur_loss_data = loss_data[epoch]    
print(f"Epoch: {epoch+1}, Loss: {cur_loss_data['total_loss']:.2f}, Style Loss: {cur_loss_data['style_loss']:.2f}, Content Loss: {cur_loss_data['content_loss']:.2f}")
tensor_unloader(generated_image.squeeze(0))

# %%
for epoch in range(epoch+1, epoch+101):
    generated_features = NST_Network(generated_image)
    
    loss, misc_loss_data = loss_fxn(generated_features)
    loss_data[epoch] = misc_loss_data
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
cur_loss_data = loss_data[epoch]    
print(f"Epoch: {epoch+1}, Loss: {cur_loss_data['total_loss']:.2f}, Style Loss: {cur_loss_data['style_loss']:.2f}, Content Loss: {cur_loss_data['content_loss']:.2f}")
tensor_unloader(generated_image.squeeze(0))

# %%
for epoch in range(epoch+1, epoch+101):
    generated_features = NST_Network(generated_image)
    
    loss, misc_loss_data = loss_fxn(generated_features)
    loss_data[epoch] = misc_loss_data
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
cur_loss_data = loss_data[epoch]    
print(f"Epoch: {epoch+1}, Loss: {cur_loss_data['total_loss']:.2f}, Style Loss: {cur_loss_data['style_loss']:.2f}, Content Loss: {cur_loss_data['content_loss']:.2f}")
tensor_unloader(generated_image.squeeze(0))

# %%
for epoch in range(epoch+1, epoch+101):
    generated_features = NST_Network(generated_image)
    
    loss, misc_loss_data = loss_fxn(generated_features)
    loss_data[epoch] = misc_loss_data
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
cur_loss_data = loss_data[epoch]    
print(f"Epoch: {epoch+1}, Loss: {cur_loss_data['total_loss']:.2f}, Style Loss: {cur_loss_data['style_loss']:.2f}, Content Loss: {cur_loss_data['content_loss']:.2f}")
tensor_unloader(generated_image.squeeze(0))

# %%
for epoch in range(epoch+1, epoch+101):
    generated_features = NST_Network(generated_image)
    
    loss, misc_loss_data = loss_fxn(generated_features)
    loss_data[epoch] = misc_loss_data
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
cur_loss_data = loss_data[epoch]    
print(f"Epoch: {epoch+1}, Loss: {cur_loss_data['total_loss']:.2f}, Style Loss: {cur_loss_data['style_loss']:.2f}, Content Loss: {cur_loss_data['content_loss']:.2f}")
tensor_unloader(generated_image.squeeze(0))
